# %%
import os
import sys
import numpy as np
import argparse
import h5py
import math
import random
import time
import logging
import matplotlib.pyplot as plt
import sklearn
import csv

import torch
import torchaudio
#torch.backends.cudnn.benchmark=True
#torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
 
sys.path.append("utils")
from utilities import get_filename
sys.path.append("pytorch/")
from models import *
import config

from scipy.stats import pearsonr
from torchmetrics import R2Score, ConcordanceCorrCoef

# %%
class Transfer_Cnn14(nn.Module):
    def __init__(self, sample_rate, window_size, hop_size, mel_bins, fmin, 
        fmax, classes_num, freeze_base):
        """Classifier for a new task using pretrained Cnn14 as a sub module.
        """
        super(Transfer_Cnn14, self).__init__()
        audioset_classes_num = 527
        
        self.base = Cnn14(sample_rate, window_size, hop_size, mel_bins, fmin, 
            fmax, audioset_classes_num)

        # Transfer to another task layer
        self.ff_mid = nn.Linear(2048, 10, bias=True)
        #self.fc_transfer = nn.Linear(2048, classes_num, bias=True)
        self.fc_transfer = nn.Linear(10, classes_num, bias=True)
        self.gelu = nn.GELU()
        
        if freeze_base:
            # Freeze AudioSet pretrained layers
            for param in self.base.parameters():
                param.requires_grad = False

        self.init_weights()

    def init_weights(self):
        init_layer(self.fc_transfer)

    def load_from_pretrain(self, pretrained_checkpoint_path):
        checkpoint = torch.load(pretrained_checkpoint_path)
        self.base.load_state_dict(checkpoint['model'])

    def forward(self, input, mixup_lambda=None):
        """Input: (batch_size, data_length)
        """
        output_dict = self.base(input, mixup_lambda)
        embedding = output_dict['embedding']

        #clipwise_output =  torch.log_softmax(self.fc_transfer(embedding), dim=-1)
        embedding = self.gelu(self.ff_mid(embedding))
        output = self.fc_transfer(embedding)
        output_dict['regressor'] = output
 
        return output_dict

# %%
class Transfer_Cnn10(nn.Module):
    def __init__(self, sample_rate, window_size, hop_size, mel_bins, fmin, 
        fmax, classes_num, freeze_base):
        """Classifier for a new task using pretrained Cnn14 as a sub module.
        """
        super(Transfer_Cnn10, self).__init__()
        audioset_classes_num = 527
        
        self.base = Cnn10(sample_rate, window_size, hop_size, mel_bins, fmin, 
            fmax, audioset_classes_num)

        # Transfer to another task layer
        self.ff_mid = nn.Linear(512, 10, bias=True)
        #self.fc_transfer = nn.Linear(512, classes_num, bias=True)
        self.fc_transfer = nn.Linear(10, classes_num, bias=True)
        self.gelu = nn.GELU()

        if freeze_base:
            # Freeze AudioSet pretrained layers
            for param in self.base.parameters():
                param.requires_grad = False

        self.init_weights()

    def init_weights(self):
        init_layer(self.fc_transfer)

    def load_from_pretrain(self, pretrained_checkpoint_path):
        checkpoint = torch.load(pretrained_checkpoint_path)
        self.base.load_state_dict(checkpoint['model'])

    def forward(self, input, mixup_lambda=None):
        """Input: (batch_size, data_length)
        """
        output_dict = self.base(input, mixup_lambda)
        embedding = output_dict['embedding']
        #print(embedding.shape)
        #print(self.fc_transfer(embedding).shape)
        #clipwise_output =  torch.log_softmax(self.fc_transfer(embedding), dim=-1)

        embedding = self.gelu(self.ff_mid(embedding))
        output = self.fc_transfer(embedding)
        output_dict['regressor'] = output
 
        return output_dict

# %%
class Transfer_Cnn6(nn.Module):
    def __init__(self, sample_rate, window_size, hop_size, mel_bins, fmin, 
        fmax, classes_num, freeze_base):
        """Classifier for a new task using pretrained Cnn14 as a sub module.
        """
        super(Transfer_Cnn6, self).__init__()
        audioset_classes_num = 527
        
        self.base = Cnn6(sample_rate, window_size, hop_size, mel_bins, fmin, 
            fmax, audioset_classes_num)

        # Transfer to another task layer
        self.ff_mid = nn.Linear(512, 10, bias=True)
        #self.fc_transfer = nn.Linear(512, classes_num, bias=True)
        self.fc_transfer = nn.Linear(10, classes_num, bias=True)
        self.gelu = nn.GELU()

        if freeze_base:
            # Freeze AudioSet pretrained layers
            for param in self.base.parameters():
                param.requires_grad = False

        self.init_weights()

    def init_weights(self):
        init_layer(self.fc_transfer)

    def load_from_pretrain(self, pretrained_checkpoint_path):
        checkpoint = torch.load(pretrained_checkpoint_path)
        self.base.load_state_dict(checkpoint['model'])

    def forward(self, input, mixup_lambda=None):
        """Input: (batch_size, data_length)
        """
        output_dict = self.base(input, mixup_lambda)
        embedding = output_dict['embedding']
        #print(embedding.shape)
        #print(self.fc_transfer(embedding).shape)
        #clipwise_output =  torch.log_softmax(self.fc_transfer(embedding), dim=-1)

        embedding = self.gelu(self.ff_mid(embedding))
        output = self.fc_transfer(embedding)
        output_dict['regressor'] = output
 
        return output_dict

# %%
def extract_index_from_path(data_path_with_index):
    position_in_path = data_path_with_index.rfind('_')
    file_path = data_path_with_index[:position_in_path]
    index = int(data_path_with_index[(position_in_path+1):])
    return file_path, index

# %%
import pandas

folder = '../alunos_finger_Tinder/SPIRA_Dataset_V2/'

def create_data_paths_list(csv_file, folder=folder):
    csv = pandas.read_csv(csv_file)

    file_paths = []
    for file_path in csv['arquivo']:
        data_path_with_index = folder+file_path
        file_paths.append(data_path_with_index)
    
    oxigen_saturation_list = []
    for oxigen_saturation_val in csv['oxigenacao']:
        oxigen_saturation_list.append(oxigen_saturation_val)

    #merge
    data_paths_list = []
    for index in range(len(file_paths)):
        data_path_with_index = file_paths[index]
        oxigen_saturation_val = oxigen_saturation_list[index]
        data_path_oxygen_saturation = (data_path_with_index, oxigen_saturation_val)
        data_paths_list.append(data_path_oxygen_saturation)
        
    random.shuffle(data_paths_list)
    
    return data_paths_list
        
csv_file = '../alunos_finger_Tinder/SPIRA_Dataset_V2/metadata_cv_index.csv'
data_paths = create_data_paths_list(csv_file)

# %%
#build function to process data in batches
def process_batches(data_paths, number_coeffs, min_frequency, max_frequency, batch_size, pretrain, path_index):
    
    #parameters below maybe should be defined elsewhere
    #set audio length in seconds - this is max length of audios
    audio_length = 4
    device = 'cuda'
    new_sample_rate = 16000
    
    
    
    ################################
    
    data_batch = []
    
    data_target_list = []

    while len(data_batch) < batch_size and path_index < len(data_paths):
        data_path_oxygen_saturation = data_paths[path_index]
        data_path_with_index = data_path_oxygen_saturation[0]
        oxygen_saturation_val = data_path_oxygen_saturation[1]
        
        data_path, index = extract_index_from_path(data_path_with_index)
        sample_rate = torchaudio.info(data_path).sample_rate
        
        data_elem, sample_rate = torchaudio.load(data_path, frame_offset=index*sample_rate, num_frames = audio_length*sample_rate)
        #downsampling to fit gpu memory
        data_elem = torchaudio.transforms.Resample(sample_rate, new_sample_rate)(data_elem)
        sample_rate = new_sample_rate
        data_elem = data_elem[0]
        
        data_batch.append(data_elem)
        
        #for supervised training we store whether the file comes from patient/healthy group
        data_target_list.append(oxygen_saturation_val)
        #######################
        
        path_index +=1
            
    #convert list to torch tensor (pads different audio lengths to same size)
    data_batch = nn.utils.rnn.pad_sequence(data_batch, batch_first=True)
    
    data_batch = data_batch.to(device)
    
    #for supervised training
    data_target_list = torch.FloatTensor(data_target_list)
    data_target_list = data_target_list.to(device)
    ###########################
    

    return data_batch, data_target_list, path_index

# %%
#function to train model
def run_epoch(model, loss_compute, data_paths, avg_loss=0, pretrain='pretrain', training=True, batch_size=16, extract_coeffs='both', min_frequency = 0.0, max_frequency=None, number_coeffs=128, mask_proportion=0., mask_consecutive_frames=7, mask_frequency_proportion=0., random_noise_proportion=0.0):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    train_acc_avg = 0
    f1_score_avg = 0
    
    number_elements = len(data_paths)
    #number_steps = int(math.ceil(number_elements/batch_size))
    
    outputs=[]
    targets=[]
    
    #path index is the index of the audio file in the filenames list
    path_index = 0
    #step index stores the amount of steps taken by the algorithm so far
    step_index = 0
    while path_index < number_elements:
        step_index +=1
        #load the data and mask it
        data_batch, data_target_list, path_index = process_batches(data_paths, number_coeffs, min_frequency, max_frequency, batch_size, pretrain, path_index)
        b_size = data_batch.shape[0]
        #pass data through transformer
        #print(data_batch.shape)
        out = model.forward(data_batch)
        #compute loss
        #print('out', out.shape)
        #print('data_batch', data_batch.shape)
        if pretrain=='pretrain':
            #print('data_batch')
            loss = loss_compute(out, data_batch, training)
        else:
            loss, output, target = loss_compute(out, data_target_list, training)
        
        outputs.append(output)
        targets.append(target)

        total_loss += loss
        avg_loss = avg_loss*0.99 + loss*0.01
        total_tokens += b_size
        tokens += b_size
        true_avg_loss = total_loss/step_index
        
        #if path_index > 10:
        #    break
        
        if step_index % 5 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f True Avg Loss: %f" %
                    (step_index, avg_loss, tokens / elapsed, true_avg_loss))
            start = time.time()
            tokens = 0

    outputs = np.concatenate(outputs)
    targets = np.concatenate(targets)
    
    abs_diff = np.abs(outputs-targets)
    diff_mean = np.mean(abs_diff)
    diff_std = np.std(abs_diff)
    
    corr_matrix = np.corrcoef(targets[:,0], outputs[:,0])
    corr = corr_matrix[0,1]
    R_sq = corr**2
    #Calculo Pearson https://www.geeksforgeeks.org/python-pearson-correlation-test-between-two-variables/
    pearson, _ = pearsonr(outputs[:,0], targets[:,0])

    print("Loss:", true_avg_loss)
    print("R2:", R_sq)
    print("Pearson:", pearson)

    if training == False:
        for res in ["Saida: {}  Alvo: {}".format(x,y) for x,y in zip(outputs,targets)] :
            print(res)

    print("Diff mean:", diff_mean)
    print("Diff std:", diff_std)

    return total_loss / (total_tokens), avg_loss, true_avg_loss, diff_mean, diff_std, R_sq, pearson

# %%
class NoamOpt:
    "Optim wrapper that implements rate."
    def __init__(self, model_size, factor, warmup, optimizer):
        self.optimizer = optimizer
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0
        
    def step(self):
        "Update parameters and rate"
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        self.optimizer.step()
        
    def rate(self, step = None):
        "Implement `lrate` above"
        if step is None:
            step = self._step
        #return self.factor * \
        #    (self.model_size ** (-0.5) *
        #    min(step ** (-0.5), step * self.warmup ** (-1.5)))
        return 1e-4
        
def get_std_opt(model):
    return NoamOpt(model.src_embed[0].d_model, 2, 4000,
            torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))

# %%
class LossCompute:
    "A simple loss compute and train function."
    def __init__(self, model, opt=None, pretrain='pretrain', loss_function = 'MAE'):
        self.model = model
        self.opt = opt
        self.pretrain = pretrain
        self.loss_function = loss_function
        
    def __call__(self, output_dict, y, training):
        train_acc = 0
        if self.pretrain == 'pretrain':
            L1_loss = nn.L1Loss()
            loss = L1_loss(output_dict['clipwise_output'], y)
        else:
            if self.loss_function == 'MAE':#mae loss
                loss_fct = nn.L1Loss()
            else:#MSE loss
                loss_fct = nn.MSELoss()
            #check the indices for cross entropy loss
            y = y.unsqueeze(1)
            loss = loss_fct(output_dict['regressor'], y)
            preds = output_dict['regressor'].detach().cpu().clone()
            y_true = y.detach().cpu().clone()

        if training == True:
            loss.backward()
            if self.opt is not None:
                self.opt.step()
                self.opt.optimizer.zero_grad()
        return loss.data.item(), preds, y_true

# %%
args = {}
args['sample_rate']= 32000
args['window_size']= 1024
args['hop_size']=320
args['mel_bins']=64
args['fmin']=0
args['fmax']=32000
args['model_type']="Transfer_Cnn6"
args['pretrained_checkpoint_path']="../../spira_segunda_fase_coleta/Pretrained_audio_neural_networks/Cnn6.pth"
args['freeze_base']=False
args['cuda']=True

# %%
pretrain = 'ri'
loss_function = 'MSE'
d_model = 2048

# Arguments & parameters
sample_rate = args['sample_rate']
window_size = args['window_size']
hop_size = args['hop_size']
mel_bins = args['mel_bins']
fmin = args['fmin']
fmax = args['fmax']
model_type = args['model_type']
pretrained_checkpoint_path = args['pretrained_checkpoint_path']
freeze_base = args['freeze_base']
device = 'cuda' if (args['cuda'] and torch.cuda.is_available()) else 'cpu'
classes_num = 1#config.classes_num
pretrain = True if pretrained_checkpoint_path else False


cv_folds = 10
data_points = len(data_paths)
fold_size = int(data_points/cv_folds)

pearson_fold = []
R2_fold = []
MSE_fold = []
MAE_fold = []
MAE_std_fold = []

for i in range(cv_folds):
    slice_start = fold_size*i
    slice_end = fold_size*(i+1)
    data_paths_test = data_paths[slice_start:slice_end]
    data_paths_train = data_paths[:slice_start]+data_paths[slice_end:]


    # Model
    Model = eval(model_type)
    model = Model(sample_rate, window_size, hop_size, mel_bins, fmin, fmax, classes_num, freeze_base)
    model_opt = NoamOpt(d_model, 1, 10,
        torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))


    # Load pretrained model
    if pretrain:
        logging.info('Load pretrained model from {}'.format(pretrained_checkpoint_path))
        model.load_from_pretrain(pretrained_checkpoint_path)


    if 'cuda' in device:
        model.to(device)

    print('Load pretrained model successfully!')

    
    avg_loss=0
    model_path = 'model_test_mel.ckpt'
    min_frequency = 0.0
    max_frequency = None
    model.train()
    for epoch in range(20):
        loss, avg_loss, _, _, _, _, _ = run_epoch(model, 
                  LossCompute(model, model_opt, pretrain, loss_function),
                  data_paths_train, pretrain=pretrain, training=True, avg_loss=avg_loss,
                  min_frequency=min_frequency, max_frequency=max_frequency, number_coeffs=64)
    model.eval()
    with torch.no_grad():
        loss, avg_loss, true_avg_loss, diff_mean, diff_std, r2, pearson = run_epoch(model, 
                    LossCompute(model, None, pretrain, loss_function),
                    data_paths_test, pretrain=pretrain, training=False,
                    min_frequency=min_frequency, max_frequency=max_frequency, number_coeffs=64)
        print('val_true_avg_loss=', val_true_avg_loss)
        print('val_diff_mean=', val_diff_mean)
        print('val_diff_std=', val_diff_std)
        print('r2=', r2)
        print('pearson=', pearson)
        print('loss=', loss)
        
    pearson_fold.append(pearson)
    R2_fold.append(r2)
    MSE_fold.append(true_avg_loss)
    MAE_fold.append(diff_mean)
    MAE_std_fold.append(diff_std)

    
MSE_fold = np.array(MSE_fold)
MAE_fold = np.array(MAE_fold)
MAE_std_fold = np.array(MAE_std_fold)
R2_fold = np.array(R2_fold)
pearson_fold = np.array(pearson_fold)

print('========================================================================')
print("TEST SUMMARY OF THE CROSS VALIDATION")
print('========================================================================')
    
print("Avg MAE_std:", np.mean(MAE_std_fold))
print("Avg. abs error:",  np.mean(MAE_fold))
print("Avg r2:", np.mean(R2_fold))
print("Avg pearson:", np.mean(pearson_fold))
print("Avg MSE:", np.mean(MSE_fold))
# Out:
# Epoch Step: 1 Loss: 88.158203 Tokens per Sec: 62.632810 True Avg Loss: 8815.820312
# Epoch Step: 6 Loss: 507.204885 Tokens per Sec: 67.658426 True Avg Loss: 8667.562988
# Epoch Step: 11 Loss: 903.073726 Tokens per Sec: 70.414102 True Avg Loss: 8630.642933
# Epoch Step: 16 Loss: 1278.366222 Tokens per Sec: 69.569481 True Avg Loss: 8608.656128
# Epoch Step: 21 Loss: 1634.267384 Tokens per Sec: 68.619326 True Avg Loss: 8592.388625
# Epoch Step: 26 Loss: 1968.891507 Tokens per Sec: 68.150794 True Avg Loss: 8567.192195
# Epoch Step: 31 Loss: 2292.761861 Tokens per Sec: 69.371628 True Avg Loss: 8568.389428
# Epoch Step: 36 Loss: 2594.064434 Tokens per Sec: 68.881912 True Avg Loss: 8550.759793
# Epoch Step: 41 Loss: 2883.187930 Tokens per Sec: 69.021903 True Avg Loss: 8543.829102
# Epoch Step: 46 Loss: 3158.405236 Tokens per Sec: 67.616583 True Avg Loss: 8538.941258
# Epoch Step: 51 Loss: 3414.988547 Tokens per Sec: 66.556076 True Avg Loss: 8524.602156
# Epoch Step: 56 Loss: 3658.164880 Tokens per Sec: 65.756670 True Avg Loss: 8511.442365
# Epoch Step: 61 Loss: 3889.562141 Tokens per Sec: 66.953345 True Avg Loss: 8500.669458
# Epoch Step: 66 Loss: 4105.051045 Tokens per Sec: 63.076118 True Avg Loss: 8484.410097
# Epoch Step: 71 Loss: 4312.080746 Tokens per Sec: 65.747445 True Avg Loss: 8473.479520
# Epoch Step: 76 Loss: 4507.891050 Tokens per Sec: 66.491227 True Avg Loss: 8462.477526
# Epoch Step: 81 Loss: 4690.819636 Tokens per Sec: 67.437595 True Avg Loss: 8448.813284
# Epoch Step: 86 Loss: 4857.346087 Tokens per Sec: 66.370414 True Avg Loss: 8427.835018
# Epoch Step: 91 Loss: 5015.150090 Tokens per Sec: 66.397968 True Avg Loss: 8408.593825
# Epoch Step: 96 Loss: 5159.755186 Tokens per Sec: 66.032833 True Avg Loss: 8385.477865
# Epoch Step: 1 Loss: 82.499961 Tokens per Sec: 117.376952 True Avg Loss: 8249.996094
# Epoch Step: 6 Loss: 488.562206 Tokens per Sec: 117.704370 True Avg Loss: 8348.615397
# val_avg_loss= 720.3195147344225
# val_true_avg_loss= 8329.859592013889
# val_diff_mean= 91.34134
# val_diff_std= 1.8875436
# loss= 572.2804299856871
# Epoch= 0
# Saving model
# Epoch Step: 1 Loss: 5299.219884 Tokens per Sec: 63.562761 True Avg Loss: 8117.003418
# Epoch Step: 6 Loss: 5429.494326 Tokens per Sec: 66.962644 True Avg Loss: 7983.688802
# Epoch Step: 11 Loss: 5550.042337 Tokens per Sec: 65.221789 True Avg Loss: 7941.805708
# Epoch Step: 16 Loss: 5660.848548 Tokens per Sec: 65.592458 True Avg Loss: 7900.740173
# Epoch Step: 21 Loss: 5761.059488 Tokens per Sec: 65.091471 True Avg Loss: 7854.307199
# Epoch Step: 26 Loss: 5847.272557 Tokens per Sec: 62.952489 True Avg Loss: 7790.056190
# Epoch Step: 31 Loss: 5927.628033 Tokens per Sec: 64.401959 True Avg Loss: 7740.953598
# Epoch Step: 36 Loss: 5994.551487 Tokens per Sec: 63.557620 True Avg Loss: 7678.952013
# Epoch Step: 41 Loss: 6057.174056 Tokens per Sec: 64.157761 True Avg Loss: 7629.457162
# Epoch Step: 46 Loss: 6105.326822 Tokens per Sec: 65.060941 True Avg Loss: 7565.425049
# Epoch Step: 51 Loss: 6133.781313 Tokens per Sec: 63.619090 True Avg Loss: 7479.229033
# Epoch Step: 56 Loss: 6154.198346 Tokens per Sec: 64.102238 True Avg Loss: 7396.413313
# Epoch Step: 61 Loss: 6157.171753 Tokens per Sec: 67.242812 True Avg Loss: 7299.787742
# Epoch Step: 66 Loss: 6143.200890 Tokens per Sec: 64.613889 True Avg Loss: 7191.783736
# Epoch Step: 71 Loss: 6113.701725 Tokens per Sec: 64.869629 True Avg Loss: 7075.626616
# Epoch Step: 76 Loss: 6073.590185 Tokens per Sec: 64.854032 True Avg Loss: 6958.524909
# Epoch Step: 81 Loss: 6019.157948 Tokens per Sec: 64.884782 True Avg Loss: 6835.514564
# Epoch Step: 86 Loss: 5952.416135 Tokens per Sec: 64.375407 True Avg Loss: 6708.967666
# Epoch Step: 91 Loss: 5876.875551 Tokens per Sec: 65.388416 True Avg Loss: 6582.721825
# Epoch Step: 96 Loss: 5785.753457 Tokens per Sec: 64.724154 True Avg Loss: 6449.068499
# Epoch Step: 1 Loss: 50.599443 Tokens per Sec: 95.768701 True Avg Loss: 5059.944336
# Epoch Step: 6 Loss: 299.885443 Tokens per Sec: 115.099751 True Avg Loss: 5124.475911
# val_avg_loss= 445.0041314489595
# val_true_avg_loss= 5145.142252604167
# val_diff_mean= 71.67112
# val_diff_std= 3.5781736
# loss= 353.4830555224237
# Epoch= 1
# Saving model
# Epoch Step: 1 Loss: 5689.169274 Tokens per Sec: 63.864180 True Avg Loss: 3962.802246
# Epoch Step: 6 Loss: 5580.634568 Tokens per Sec: 65.312445 True Avg Loss: 3558.153727
# Epoch Step: 11 Loss: 5468.341640 Tokens per Sec: 63.434845 True Avg Loss: 3437.270020
# Epoch Step: 16 Loss: 5350.034316 Tokens per Sec: 64.632483 True Avg Loss: 3317.758926
# Epoch Step: 21 Loss: 5219.027216 Tokens per Sec: 62.544166 True Avg Loss: 3165.443848
# Epoch Step: 26 Loss: 5085.743994 Tokens per Sec: 62.325541 True Avg Loss: 3037.326303
# Epoch Step: 31 Loss: 4947.050444 Tokens per Sec: 62.233342 True Avg Loss: 2911.510896
# Epoch Step: 36 Loss: 4806.267348 Tokens per Sec: 63.921824 True Avg Loss: 2795.705156
# Epoch Step: 41 Loss: 4658.814245 Tokens per Sec: 63.704339 True Avg Loss: 2673.970763
# Epoch Step: 46 Loss: 4518.704498 Tokens per Sec: 64.142418 True Avg Loss: 2579.183249
# Epoch Step: 51 Loss: 4368.665868 Tokens per Sec: 63.377776 True Avg Loss: 2469.077670
# Epoch Step: 56 Loss: 4218.647473 Tokens per Sec: 62.149012 True Avg Loss: 2365.333017
# Epoch Step: 61 Loss: 4069.198972 Tokens per Sec: 63.575961 True Avg Loss: 2267.353861
# Epoch Step: 66 Loss: 3921.557835 Tokens per Sec: 63.677826 True Avg Loss: 2175.646742
# Epoch Step: 71 Loss: 3773.166904 Tokens per Sec: 64.256972 True Avg Loss: 2085.441288
# Epoch Step: 76 Loss: 3626.130398 Tokens per Sec: 63.112599 True Avg Loss: 1999.096157
# Epoch Step: 81 Loss: 3478.513813 Tokens per Sec: 62.195541 True Avg Loss: 1913.656409
# Epoch Step: 86 Loss: 3337.477737 Tokens per Sec: 62.507208 True Avg Loss: 1837.352901
# Epoch Step: 91 Loss: 3203.900481 Tokens per Sec: 62.100289 True Avg Loss: 1770.066203
# Epoch Step: 96 Loss: 3068.956806 Tokens per Sec: 62.319579 True Avg Loss: 1701.309302
# Epoch Step: 1 Loss: 17.712534 Tokens per Sec: 115.728682 True Avg Loss: 1771.253418
# Epoch Step: 6 Loss: 108.166813 Tokens per Sec: 114.532012 True Avg Loss: 1847.911804
# val_avg_loss= 163.84035469838182
# val_true_avg_loss= 1893.0037841796875
# val_diff_mean= 43.016663
# val_diff_std= 6.248926
# loss= 130.0536950963144
# Epoch= 2
# Saving model
# Epoch Step: 1 Loss: 2940.294190 Tokens per Sec: 56.784336 True Avg Loss: 583.180054
# Epoch Step: 6 Loss: 2820.145872 Tokens per Sec: 64.842289 True Avg Loss: 503.836573
# Epoch Step: 11 Loss: 2699.347289 Tokens per Sec: 65.075906 True Avg Loss: 436.413910
# Epoch Step: 16 Loss: 2589.404110 Tokens per Sec: 65.119098 True Avg Loss: 442.789707
# Epoch Step: 21 Loss: 2480.978365 Tokens per Sec: 64.077303 True Avg Loss: 427.583923
# Epoch Step: 26 Loss: 2373.598049 Tokens per Sec: 63.968777 True Avg Loss: 401.389887
# Epoch Step: 31 Loss: 2268.032921 Tokens per Sec: 64.129510 True Avg Loss: 372.105810
# Epoch Step: 36 Loss: 2168.837240 Tokens per Sec: 64.136570 True Avg Loss: 354.414231
# Epoch Step: 41 Loss: 2072.937081 Tokens per Sec: 63.900022 True Avg Loss: 336.979569
# Epoch Step: 46 Loss: 1984.803433 Tokens per Sec: 64.568805 True Avg Loss: 330.125567
# Epoch Step: 51 Loss: 1901.752025 Tokens per Sec: 63.805209 True Avg Loss: 326.191666
# Epoch Step: 56 Loss: 1818.495324 Tokens per Sec: 63.842964 True Avg Loss: 315.263517
# Epoch Step: 61 Loss: 1739.222862 Tokens per Sec: 64.961484 True Avg Loss: 305.932661
# Epoch Step: 66 Loss: 1664.559558 Tokens per Sec: 64.046506 True Avg Loss: 299.090494
# Epoch Step: 71 Loss: 1592.190522 Tokens per Sec: 63.083434 True Avg Loss: 291.284913
# Epoch Step: 76 Loss: 1522.653809 Tokens per Sec: 65.510026 True Avg Loss: 283.526577
# Epoch Step: 81 Loss: 1458.170386 Tokens per Sec: 61.034902 True Avg Loss: 278.863991
# Epoch Step: 86 Loss: 1395.870545 Tokens per Sec: 66.169887 True Avg Loss: 273.556975
# Epoch Step: 91 Loss: 1340.381145 Tokens per Sec: 63.754546 True Avg Loss: 273.048138
# Epoch Step: 96 Loss: 1286.073964 Tokens per Sec: 62.360719 True Avg Loss: 270.899398
# Epoch Step: 1 Loss: 10.791260 Tokens per Sec: 117.483188 True Avg Loss: 1079.125977
# Epoch Step: 6 Loss: 62.515180 Tokens per Sec: 115.137390 True Avg Loss: 1068.113912
# val_avg_loss= 93.0790737631108
# val_true_avg_loss= 1076.2868245442708
# val_diff_mean= 32.718704
# val_diff_std= 4.732556
# loss= 73.94336962517892
# Epoch= 3
# Saving model
# Epoch Step: 1 Loss: 1231.500200 Tokens per Sec: 57.212234 True Avg Loss: 160.183990
# Epoch Step: 6 Loss: 1181.945546 Tokens per Sec: 65.344345 True Avg Loss: 210.227295
# Epoch Step: 11 Loss: 1133.407034 Tokens per Sec: 67.135651 True Avg Loss: 201.977671
# Epoch Step: 16 Loss: 1084.551570 Tokens per Sec: 65.697189 True Avg Loss: 181.600003
# Epoch Step: 21 Loss: 1041.827010 Tokens per Sec: 64.938603 True Avg Loss: 188.900811
# Epoch Step: 26 Loss: 1000.426018 Tokens per Sec: 63.411109 True Avg Loss: 190.526001
# Epoch Step: 31 Loss: 963.552164 Tokens per Sec: 63.903941 True Avg Loss: 199.937322
# Epoch Step: 36 Loss: 925.577840 Tokens per Sec: 64.399549 True Avg Loss: 198.390635
# Epoch Step: 41 Loss: 888.676444 Tokens per Sec: 64.206266 True Avg Loss: 195.236894
# Epoch Step: 46 Loss: 855.016574 Tokens per Sec: 64.508724 True Avg Loss: 195.935355
# Epoch Step: 51 Loss: 824.009839 Tokens per Sec: 63.912400 True Avg Loss: 198.473609
# Epoch Step: 56 Loss: 792.776816 Tokens per Sec: 65.330604 True Avg Loss: 197.381935
# Epoch Step: 61 Loss: 761.533976 Tokens per Sec: 64.778622 True Avg Loss: 193.939403
# Epoch Step: 66 Loss: 731.145102 Tokens per Sec: 64.969924 True Avg Loss: 189.937079
# Epoch Step: 71 Loss: 702.816953 Tokens per Sec: 66.386985 True Avg Loss: 187.367837
# Epoch Step: 76 Loss: 676.502901 Tokens per Sec: 64.310323 True Avg Loss: 185.934416
# Epoch Step: 81 Loss: 654.564485 Tokens per Sec: 63.915870 True Avg Loss: 188.553425
# Epoch Step: 86 Loss: 630.457870 Tokens per Sec: 63.079118 True Avg Loss: 187.033672
# Epoch Step: 91 Loss: 604.981771 Tokens per Sec: 62.958123 True Avg Loss: 182.838437
# Epoch Step: 96 Loss: 581.783600 Tokens per Sec: 64.904650 True Avg Loss: 180.164846
# Epoch Step: 1 Loss: 7.860017 Tokens per Sec: 120.843060 True Avg Loss: 786.001709
# Epoch Step: 6 Loss: 43.240925 Tokens per Sec: 121.221871 True Avg Loss: 738.859192
# val_avg_loss= 64.57540696759739
# val_true_avg_loss= 746.7822333441841
# val_diff_mean= 27.109837
# val_diff_std= 5.3990273
# loss= 51.30564961906608
# Epoch= 4
# Saving model
# Epoch Step: 1 Loss: 560.815361 Tokens per Sec: 55.997597 True Avg Loss: 157.891876
# Epoch Step: 6 Loss: 541.922975 Tokens per Sec: 66.503351 True Avg Loss: 172.872843
# Epoch Step: 11 Loss: 523.801707 Tokens per Sec: 64.646280 True Avg Loss: 172.540175
# Epoch Step: 16 Loss: 506.977787 Tokens per Sec: 65.929504 True Avg Loss: 175.000458
# Epoch Step: 21 Loss: 491.557618 Tokens per Sec: 63.784796 True Avg Loss: 179.011676
# Epoch Step: 26 Loss: 474.416327 Tokens per Sec: 64.525520 True Avg Loss: 171.711973
# Epoch Step: 31 Loss: 459.579738 Tokens per Sec: 63.741079 True Avg Loss: 171.562320
# Epoch Step: 36 Loss: 444.464463 Tokens per Sec: 64.509790 True Avg Loss: 168.755321
# Epoch Step: 41 Loss: 428.812224 Tokens per Sec: 63.743234 True Avg Loss: 163.447882
# Epoch Step: 46 Loss: 414.494528 Tokens per Sec: 65.143801 True Avg Loss: 160.526423
# Epoch Step: 51 Loss: 403.760325 Tokens per Sec: 64.200136 True Avg Loss: 163.979137
# Epoch Step: 56 Loss: 393.052389 Tokens per Sec: 65.358664 True Avg Loss: 165.928249
# Epoch Step: 61 Loss: 380.476841 Tokens per Sec: 65.366761 True Avg Loss: 163.507368
# Epoch Step: 66 Loss: 369.434951 Tokens per Sec: 65.438035 True Avg Loss: 162.888441
# Epoch Step: 71 Loss: 357.628186 Tokens per Sec: 65.111883 True Avg Loss: 160.444868
# Epoch Step: 76 Loss: 347.306578 Tokens per Sec: 64.464318 True Avg Loss: 159.532519
# Epoch Step: 81 Loss: 338.864937 Tokens per Sec: 65.094375 True Avg Loss: 160.458005
# Epoch Step: 86 Loss: 327.356344 Tokens per Sec: 64.618543 True Avg Loss: 157.147956
# Epoch Step: 91 Loss: 318.401254 Tokens per Sec: 64.511713 True Avg Loss: 156.459044
# Epoch Step: 96 Loss: 308.975559 Tokens per Sec: 65.345833 True Avg Loss: 154.885589
# Epoch Step: 1 Loss: 4.677050 Tokens per Sec: 120.644498 True Avg Loss: 467.705017
# Epoch Step: 6 Loss: 25.940002 Tokens per Sec: 116.305112 True Avg Loss: 443.193197
# val_avg_loss= 38.93258388598192
# val_true_avg_loss= 450.2129177517361
# val_diff_mean= 20.969095
# val_diff_std= 4.9023485
# loss= 30.93065847149332
# Epoch= 5
# Saving model
# Epoch Step: 1 Loss: 300.699815 Tokens per Sec: 57.835866 True Avg Loss: 233.083008
# Epoch Step: 6 Loss: 295.610657 Tokens per Sec: 66.249136 True Avg Loss: 202.750014
# Epoch Step: 11 Loss: 290.395844 Tokens per Sec: 66.626700 True Avg Loss: 196.654467
# Epoch Step: 16 Loss: 286.181778 Tokens per Sec: 66.356081 True Avg Loss: 199.102139
# Epoch Step: 21 Loss: 279.279165 Tokens per Sec: 64.751345 True Avg Loss: 186.310880
# Epoch Step: 26 Loss: 273.870880 Tokens per Sec: 66.157649 True Avg Loss: 182.907768
# Epoch Step: 31 Loss: 267.647091 Tokens per Sec: 64.527195 True Avg Loss: 177.043981
# Epoch Step: 36 Loss: 262.851629 Tokens per Sec: 65.467144 True Avg Loss: 176.084037
# Epoch Step: 41 Loss: 255.948281 Tokens per Sec: 64.983979 True Avg Loss: 169.528477
# Epoch Step: 46 Loss: 252.888092 Tokens per Sec: 65.873680 True Avg Loss: 172.083574
# Epoch Step: 51 Loss: 247.259842 Tokens per Sec: 65.360370 True Avg Loss: 168.753064
# Epoch Step: 56 Loss: 243.510826 Tokens per Sec: 65.527591 True Avg Loss: 168.928555
# Epoch Step: 61 Loss: 238.877458 Tokens per Sec: 67.094130 True Avg Loss: 167.357614
# Epoch Step: 66 Loss: 235.252213 Tokens per Sec: 66.188356 True Avg Loss: 167.208207
# Epoch Step: 71 Loss: 232.007424 Tokens per Sec: 67.226241 True Avg Loss: 167.330588
# Epoch Step: 76 Loss: 228.759944 Tokens per Sec: 66.190745 True Avg Loss: 167.235706
# Epoch Step: 81 Loss: 224.250838 Tokens per Sec: 65.777359 True Avg Loss: 165.373131
# Epoch Step: 86 Loss: 220.201642 Tokens per Sec: 66.453052 True Avg Loss: 164.019397
# Epoch Step: 91 Loss: 215.848334 Tokens per Sec: 64.668919 True Avg Loss: 162.219215
# Epoch Step: 96 Loss: 213.140489 Tokens per Sec: 64.792281 True Avg Loss: 162.135800
# Epoch Step: 1 Loss: 5.803326 Tokens per Sec: 110.965194 True Avg Loss: 580.332581
# Epoch Step: 6 Loss: 31.532884 Tokens per Sec: 111.863879 True Avg Loss: 538.881271
# val_avg_loss= 47.03541410611513
# val_true_avg_loss= 544.0076870388455
# val_diff_mean= 23.230125
# val_diff_std= 4.0667305
# loss= 37.374573918699305
# Epoch= 6
# Epoch Step: 1 Loss: 209.778685 Tokens per Sec: 63.125280 True Avg Loss: 113.874458
# Epoch Step: 6 Loss: 206.205687 Tokens per Sec: 64.015409 True Avg Loss: 132.872211
# Epoch Step: 11 Loss: 201.858012 Tokens per Sec: 64.136067 True Avg Loss: 125.731112
# Epoch Step: 16 Loss: 198.955279 Tokens per Sec: 64.489655 True Avg Loss: 131.042944
# Epoch Step: 21 Loss: 197.293679 Tokens per Sec: 64.484686 True Avg Loss: 139.171885
# Epoch Step: 26 Loss: 194.622833 Tokens per Sec: 65.119768 True Avg Loss: 139.796364
# Epoch Step: 31 Loss: 191.021211 Tokens per Sec: 65.039427 True Avg Loss: 136.767785
# Epoch Step: 36 Loss: 189.397044 Tokens per Sec: 63.424976 True Avg Loss: 139.748121
# Epoch Step: 41 Loss: 185.235774 Tokens per Sec: 63.557163 True Avg Loss: 135.456413
# Epoch Step: 46 Loss: 183.563794 Tokens per Sec: 63.749628 True Avg Loss: 137.173880
# Epoch Step: 51 Loss: 181.217096 Tokens per Sec: 64.189365 True Avg Loss: 136.972420
# Epoch Step: 56 Loss: 178.472619 Tokens per Sec: 63.510571 True Avg Loss: 135.923401
# Epoch Step: 61 Loss: 176.590181 Tokens per Sec: 65.020056 True Avg Loss: 136.273624
# Epoch Step: 66 Loss: 175.487683 Tokens per Sec: 63.510246 True Avg Loss: 137.627818
# Epoch Step: 71 Loss: 173.737453 Tokens per Sec: 64.869955 True Avg Loss: 137.789620
# Epoch Step: 76 Loss: 170.043757 Tokens per Sec: 64.879011 True Avg Loss: 135.193429
# Epoch Step: 81 Loss: 168.800630 Tokens per Sec: 64.131789 True Avg Loss: 135.789343
# Epoch Step: 86 Loss: 168.025969 Tokens per Sec: 65.086749 True Avg Loss: 136.809448
# Epoch Step: 91 Loss: 166.432980 Tokens per Sec: 61.219019 True Avg Loss: 136.770925
# Epoch Step: 96 Loss: 164.604256 Tokens per Sec: 63.997913 True Avg Loss: 136.369305
# Epoch Step: 1 Loss: 4.037065 Tokens per Sec: 115.729281 True Avg Loss: 403.706543
# Epoch Step: 6 Loss: 22.355862 Tokens per Sec: 116.664402 True Avg Loss: 381.938471
# val_avg_loss= 33.79459604181104
# val_true_avg_loss= 390.6881679958767
# val_diff_mean= 19.527046
# val_diff_std= 4.3686028
# loss= 26.841171847044965
# Epoch= 7
# Saving model
# Epoch Step: 1 Loss: 161.381586 Tokens per Sec: 58.770711 True Avg Loss: 81.338776
# Epoch Step: 6 Loss: 161.030007 Tokens per Sec: 65.862379 True Avg Loss: 142.070218
# Epoch Step: 11 Loss: 162.275534 Tokens per Sec: 66.465715 True Avg Loss: 162.250273
# Epoch Step: 16 Loss: 159.356446 Tokens per Sec: 66.574590 True Avg Loss: 143.795448
# Epoch Step: 21 Loss: 157.332768 Tokens per Sec: 65.531469 True Avg Loss: 137.723950
# Epoch Step: 26 Loss: 155.781106 Tokens per Sec: 66.126697 True Avg Loss: 135.398168
# Epoch Step: 31 Loss: 155.808564 Tokens per Sec: 65.983684 True Avg Loss: 138.795470
# Epoch Step: 36 Loss: 154.915996 Tokens per Sec: 66.133344 True Avg Loss: 138.680608
# Epoch Step: 41 Loss: 154.244102 Tokens per Sec: 65.716142 True Avg Loss: 139.041825
# Epoch Step: 46 Loss: 151.813896 Tokens per Sec: 66.675367 True Avg Loss: 135.277335
# Epoch Step: 51 Loss: 150.844632 Tokens per Sec: 65.495743 True Avg Loss: 134.960506
# Epoch Step: 56 Loss: 149.276830 Tokens per Sec: 64.932470 True Avg Loss: 133.535144
# Epoch Step: 61 Loss: 147.470075 Tokens per Sec: 66.960921 True Avg Loss: 131.793092
# Epoch Step: 66 Loss: 147.484210 Tokens per Sec: 65.758925 True Avg Loss: 133.013529
# Epoch Step: 71 Loss: 145.484672 Tokens per Sec: 66.562215 True Avg Loss: 131.146154
# Epoch Step: 76 Loss: 144.672162 Tokens per Sec: 65.974252 True Avg Loss: 130.973697
# Epoch Step: 81 Loss: 143.330491 Tokens per Sec: 65.283828 True Avg Loss: 130.112126
# Epoch Step: 86 Loss: 141.316135 Tokens per Sec: 64.586267 True Avg Loss: 128.484137
# Epoch Step: 91 Loss: 142.764030 Tokens per Sec: 65.380683 True Avg Loss: 130.811525
# Epoch Step: 96 Loss: 142.927459 Tokens per Sec: 65.283536 True Avg Loss: 131.625499
# Epoch Step: 1 Loss: 4.388727 Tokens per Sec: 121.144099 True Avg Loss: 438.872742
# Epoch Step: 6 Loss: 24.319960 Tokens per Sec: 118.980850 True Avg Loss: 415.562419
# val_avg_loss= 36.01228692526526
# val_true_avg_loss= 416.574225531684
# val_diff_mean= 20.2235
# val_diff_std= 4.2073245
# loss= 28.61960328080272
# Epoch= 8
# Epoch Step: 1 Loss: 143.913939 Tokens per Sec: 65.883626 True Avg Loss: 259.406006
# Epoch Step: 6 Loss: 143.526862 Tokens per Sec: 66.576122 True Avg Loss: 156.431032
# Epoch Step: 11 Loss: 142.584191 Tokens per Sec: 66.354362 True Avg Loss: 141.740112
# Epoch Step: 16 Loss: 143.742040 Tokens per Sec: 65.548162 True Avg Loss: 149.460711
# Epoch Step: 21 Loss: 141.637646 Tokens per Sec: 65.101271 True Avg Loss: 137.859851
# Epoch Step: 26 Loss: 141.553489 Tokens per Sec: 65.888749 True Avg Loss: 138.323645
# Epoch Step: 31 Loss: 142.367168 Tokens per Sec: 64.337759 True Avg Loss: 141.472310
# Epoch Step: 36 Loss: 141.640775 Tokens per Sec: 63.845649 True Avg Loss: 139.525163
# Epoch Step: 41 Loss: 140.657778 Tokens per Sec: 62.991607 True Avg Loss: 137.349969
# Epoch Step: 46 Loss: 140.780327 Tokens per Sec: 63.359083 True Avg Loss: 137.941186
# Epoch Step: 51 Loss: 138.526366 Tokens per Sec: 63.492100 True Avg Loss: 133.678333
# Epoch Step: 56 Loss: 138.729958 Tokens per Sec: 64.316745 True Avg Loss: 134.503847
# Epoch Step: 61 Loss: 137.337392 Tokens per Sec: 65.803055 True Avg Loss: 132.524852
# Epoch Step: 66 Loss: 137.041002 Tokens per Sec: 64.713244 True Avg Loss: 132.417894
# Epoch Step: 71 Loss: 136.105927 Tokens per Sec: 66.019256 True Avg Loss: 131.406394
# Epoch Step: 76 Loss: 136.479737 Tokens per Sec: 64.690026 True Avg Loss: 132.184733
# Epoch Step: 81 Loss: 136.496564 Tokens per Sec: 64.928927 True Avg Loss: 132.434428
# Epoch Step: 86 Loss: 136.940257 Tokens per Sec: 65.011187 True Avg Loss: 133.184957
# Epoch Step: 91 Loss: 135.926846 Tokens per Sec: 65.894287 True Avg Loss: 132.266552
# Epoch Step: 96 Loss: 135.781949 Tokens per Sec: 65.539392 True Avg Loss: 132.306392
# Epoch Step: 1 Loss: 3.094888 Tokens per Sec: 121.320838 True Avg Loss: 309.488800
# Epoch Step: 6 Loss: 16.242682 Tokens per Sec: 119.855621 True Avg Loss: 277.587001
# val_avg_loss= 24.090674351029946
# val_true_avg_loss= 278.72554863823785
# val_diff_mean= 16.402792
# val_diff_std= 4.2844343
# loss= 19.14908349423008
# Epoch= 9
# Saving model
# Epoch Step: 1 Loss: 135.356606 Tokens per Sec: 58.144847 True Avg Loss: 108.598488
# Epoch Step: 6 Loss: 136.052705 Tokens per Sec: 66.757094 True Avg Loss: 142.643845
# Epoch Step: 11 Loss: 134.869291 Tokens per Sec: 65.774703 True Avg Loss: 128.787442
# Epoch Step: 16 Loss: 134.785910 Tokens per Sec: 66.445709 True Avg Loss: 130.131400
# Epoch Step: 21 Loss: 132.653700 Tokens per Sec: 65.754840 True Avg Loss: 120.846117
# Epoch Step: 26 Loss: 133.994067 Tokens per Sec: 65.417788 True Avg Loss: 128.265420
# Epoch Step: 31 Loss: 132.229968 Tokens per Sec: 64.159883 True Avg Loss: 123.330506
# Epoch Step: 36 Loss: 132.724384 Tokens per Sec: 64.666252 True Avg Loss: 125.993732
# Epoch Step: 41 Loss: 132.137781 Tokens per Sec: 65.739484 True Avg Loss: 125.294402
# Epoch Step: 46 Loss: 130.888901 Tokens per Sec: 66.651078 True Avg Loss: 123.284896
# Epoch Step: 51 Loss: 130.329295 Tokens per Sec: 66.155862 True Avg Loss: 122.928474
# Epoch Step: 56 Loss: 131.413629 Tokens per Sec: 65.500525 True Avg Loss: 125.581376
# Epoch Step: 61 Loss: 134.172177 Tokens per Sec: 66.434777 True Avg Loss: 130.679013
# Epoch Step: 66 Loss: 134.666205 Tokens per Sec: 66.774298 True Avg Loss: 131.682043
# Epoch Step: 71 Loss: 134.558173 Tokens per Sec: 67.260038 True Avg Loss: 131.739461
# Epoch Step: 76 Loss: 135.352803 Tokens per Sec: 66.687307 True Avg Loss: 132.976273
# Epoch Step: 81 Loss: 134.670405 Tokens per Sec: 65.599960 True Avg Loss: 132.246023
# Epoch Step: 86 Loss: 134.919025 Tokens per Sec: 66.890200 True Avg Loss: 132.691105
# Epoch Step: 91 Loss: 133.120355 Tokens per Sec: 66.655262 True Avg Loss: 130.810533
# Epoch Step: 96 Loss: 132.140781 Tokens per Sec: 66.165698 True Avg Loss: 129.896875
# Epoch Step: 1 Loss: 2.662952 Tokens per Sec: 122.722103 True Avg Loss: 266.295227
# Epoch Step: 6 Loss: 14.414922 Tokens per Sec: 121.694842 True Avg Loss: 246.322525
# val_avg_loss= 21.461137567530738
# val_true_avg_loss= 248.27242363823785
# val_diff_mean= 15.396406
# val_diff_std= 4.4355097
# loss= 17.056884066749166
# Epoch= 10
# Saving model
# Epoch Step: 1 Loss: 130.731284 Tokens per Sec: 64.560407 True Avg Loss: 142.109253
# Epoch Step: 6 Loss: 130.920059 Tokens per Sec: 66.012359 True Avg Loss: 135.488777
# Epoch Step: 11 Loss: 130.322820 Tokens per Sec: 65.547061 True Avg Loss: 127.860284
# Epoch Step: 16 Loss: 128.932455 Tokens per Sec: 65.429868 True Avg Loss: 119.812282
# Epoch Step: 21 Loss: 129.296433 Tokens per Sec: 63.713326 True Avg Loss: 123.693216
# Epoch Step: 26 Loss: 129.330929 Tokens per Sec: 64.317177 True Avg Loss: 124.888417
# Epoch Step: 31 Loss: 127.076196 Tokens per Sec: 63.911341 True Avg Loss: 118.193490
# Epoch Step: 36 Loss: 125.444205 Tokens per Sec: 65.756258 True Avg Loss: 114.815854
# Epoch Step: 41 Loss: 125.269123 Tokens per Sec: 64.901348 True Avg Loss: 115.652804
# Epoch Step: 46 Loss: 127.197343 Tokens per Sec: 66.630563 True Avg Loss: 121.006160
# Epoch Step: 51 Loss: 126.937048 Tokens per Sec: 65.834092 True Avg Loss: 121.128773
# Epoch Step: 56 Loss: 126.382042 Tokens per Sec: 65.897574 True Avg Loss: 120.653323
# Epoch Step: 61 Loss: 126.504574 Tokens per Sec: 67.081830 True Avg Loss: 121.291236
# Epoch Step: 66 Loss: 126.952141 Tokens per Sec: 66.207018 True Avg Loss: 122.418069
# Epoch Step: 71 Loss: 128.244189 Tokens per Sec: 67.188967 True Avg Loss: 124.617861
# Epoch Step: 76 Loss: 127.854126 Tokens per Sec: 65.888232 True Avg Loss: 124.330770
# Epoch Step: 81 Loss: 128.163649 Tokens per Sec: 66.096751 True Avg Loss: 124.943856
# Epoch Step: 86 Loss: 127.336125 Tokens per Sec: 66.700616 True Avg Loss: 124.159724
# Epoch Step: 91 Loss: 125.687223 Tokens per Sec: 66.499476 True Avg Loss: 122.479497
# Epoch Step: 96 Loss: 125.416584 Tokens per Sec: 65.898791 True Avg Loss: 122.353050
# Epoch Step: 1 Loss: 3.031894 Tokens per Sec: 123.502639 True Avg Loss: 303.189392
# Epoch Step: 6 Loss: 15.880268 Tokens per Sec: 122.125585 True Avg Loss: 271.348465
# val_avg_loss= 24.314060040615278
# val_true_avg_loss= 280.98321702745227
# val_diff_mean= 16.30242
# val_diff_std= 4.4533334
# loss= 19.304190482802063
# Epoch= 11
# Epoch Step: 1 Loss: 123.144739 Tokens per Sec: 67.797757 True Avg Loss: 86.436050
# Epoch Step: 6 Loss: 121.777486 Tokens per Sec: 66.926743 True Avg Loss: 93.719383
# Epoch Step: 11 Loss: 120.995374 Tokens per Sec: 67.342529 True Avg Loss: 99.231240
# Epoch Step: 16 Loss: 120.264057 Tokens per Sec: 67.212304 True Avg Loss: 101.354145
# Epoch Step: 21 Loss: 120.368065 Tokens per Sec: 66.202799 True Avg Loss: 106.336605
# Epoch Step: 26 Loss: 120.274162 Tokens per Sec: 65.240316 True Avg Loss: 108.736578
# Epoch Step: 31 Loss: 120.474412 Tokens per Sec: 65.931771 True Avg Loss: 111.215609
# Epoch Step: 36 Loss: 119.100699 Tokens per Sec: 66.371306 True Avg Loss: 108.598127
# Epoch Step: 41 Loss: 118.611884 Tokens per Sec: 66.055100 True Avg Loss: 108.612450
# Epoch Step: 46 Loss: 118.159354 Tokens per Sec: 65.815639 True Avg Loss: 108.668033
# Epoch Step: 51 Loss: 117.360838 Tokens per Sec: 65.466071 True Avg Loss: 108.029682
# Epoch Step: 56 Loss: 116.425561 Tokens per Sec: 65.773285 True Avg Loss: 107.154824
# Epoch Step: 61 Loss: 116.015543 Tokens per Sec: 66.689666 True Avg Loss: 107.248513
# Epoch Step: 66 Loss: 118.825577 Tokens per Sec: 66.236189 True Avg Loss: 112.245492
# Epoch Step: 71 Loss: 118.622055 Tokens per Sec: 67.278770 True Avg Loss: 112.402960
# Epoch Step: 76 Loss: 117.967111 Tokens per Sec: 66.394906 True Avg Loss: 111.936021
# Epoch Step: 81 Loss: 117.208868 Tokens per Sec: 66.128978 True Avg Loss: 111.351618
# Epoch Step: 86 Loss: 117.385696 Tokens per Sec: 66.915865 True Avg Loss: 111.911878
# Epoch Step: 91 Loss: 116.024626 Tokens per Sec: 66.632971 True Avg Loss: 110.692219
# Epoch Step: 96 Loss: 115.548605 Tokens per Sec: 66.266550 True Avg Loss: 110.489053
# Epoch Step: 1 Loss: 3.063018 Tokens per Sec: 123.486277 True Avg Loss: 306.301819
# Epoch Step: 6 Loss: 16.538125 Tokens per Sec: 122.005690 True Avg Loss: 282.555064
# val_avg_loss= 24.9472291181467
# val_true_avg_loss= 288.4256083170573
# val_diff_mean= 16.721642
# val_diff_std= 3.9178867
# loss= 19.815499808042105
# Epoch= 12
# Epoch Step: 1 Loss: 114.169172 Tokens per Sec: 67.854860 True Avg Loss: 86.616562
# Epoch Step: 6 Loss: 114.471742 Tokens per Sec: 67.324653 True Avg Loss: 114.643887
# Epoch Step: 11 Loss: 115.343624 Tokens per Sec: 67.161747 True Avg Loss: 122.663704
# Epoch Step: 16 Loss: 116.256939 Tokens per Sec: 67.217811 True Avg Loss: 126.255636
# Epoch Step: 21 Loss: 117.302850 Tokens per Sec: 66.196844 True Avg Loss: 128.834973
# Epoch Step: 26 Loss: 116.658572 Tokens per Sec: 66.425926 True Avg Loss: 124.021851
# Epoch Step: 31 Loss: 118.096997 Tokens per Sec: 66.597832 True Avg Loss: 127.608011
# Epoch Step: 36 Loss: 118.671550 Tokens per Sec: 66.779321 True Avg Loss: 127.866679
# Epoch Step: 41 Loss: 120.025501 Tokens per Sec: 66.170905 True Avg Loss: 130.180537
# Epoch Step: 46 Loss: 119.219973 Tokens per Sec: 66.334069 True Avg Loss: 127.251777
# Epoch Step: 51 Loss: 120.688863 Tokens per Sec: 66.168921 True Avg Loss: 129.401510
# Epoch Step: 56 Loss: 120.458532 Tokens per Sec: 66.049223 True Avg Loss: 128.240277
# Epoch Step: 61 Loss: 119.967340 Tokens per Sec: 66.895868 True Avg Loss: 126.738319
# Epoch Step: 66 Loss: 118.978799 Tokens per Sec: 65.827441 True Avg Loss: 124.685242
# Epoch Step: 71 Loss: 121.206682 Tokens per Sec: 66.499081 True Avg Loss: 127.497900
# Epoch Step: 76 Loss: 121.608198 Tokens per Sec: 66.521031 True Avg Loss: 127.610970
# Epoch Step: 81 Loss: 120.298817 Tokens per Sec: 66.086284 True Avg Loss: 125.574546
# Epoch Step: 86 Loss: 119.196103 Tokens per Sec: 66.896788 True Avg Loss: 123.980867
# Epoch Step: 91 Loss: 118.842832 Tokens per Sec: 66.557079 True Avg Loss: 123.322625
# Epoch Step: 96 Loss: 116.775873 Tokens per Sec: 66.245016 True Avg Loss: 120.877431
# Epoch Step: 1 Loss: 2.556104 Tokens per Sec: 122.507706 True Avg Loss: 255.610413
# Epoch Step: 6 Loss: 13.840663 Tokens per Sec: 122.202664 True Avg Loss: 236.473681
# val_avg_loss= 20.86346965326298
# val_true_avg_loss= 241.20757887098523
# val_diff_mean= 15.245584
# val_diff_std= 3.697642
# loss= 16.57151305220509
# Epoch= 13
# Saving model
# Epoch Step: 1 Loss: 115.701557 Tokens per Sec: 57.015763 True Avg Loss: 124.111229
# Epoch Step: 6 Loss: 117.164056 Tokens per Sec: 67.135033 True Avg Loss: 142.008859
# Epoch Step: 11 Loss: 116.527776 Tokens per Sec: 67.476462 True Avg Loss: 124.931673
# Epoch Step: 16 Loss: 116.237966 Tokens per Sec: 67.005568 True Avg Loss: 120.441870
# Epoch Step: 21 Loss: 115.511381 Tokens per Sec: 66.036419 True Avg Loss: 115.927521
# Epoch Step: 26 Loss: 114.577453 Tokens per Sec: 65.542951 True Avg Loss: 112.224405
# Epoch Step: 31 Loss: 114.116960 Tokens per Sec: 65.951883 True Avg Loss: 111.081854
# Epoch Step: 36 Loss: 114.010205 Tokens per Sec: 66.151897 True Avg Loss: 111.189206
# Epoch Step: 41 Loss: 115.021508 Tokens per Sec: 65.870822 True Avg Loss: 114.054264
# Epoch Step: 46 Loss: 113.722031 Tokens per Sec: 66.175133 True Avg Loss: 111.291863
# Epoch Step: 51 Loss: 112.251263 Tokens per Sec: 65.289456 True Avg Loss: 108.579512
# Epoch Step: 56 Loss: 112.292676 Tokens per Sec: 66.013619 True Avg Loss: 108.984019
# Epoch Step: 61 Loss: 111.870630 Tokens per Sec: 66.867499 True Avg Loss: 108.547780
# Epoch Step: 66 Loss: 112.173950 Tokens per Sec: 66.464859 True Avg Loss: 109.251629
# Epoch Step: 71 Loss: 112.092063 Tokens per Sec: 67.227211 True Avg Loss: 109.317617
# Epoch Step: 76 Loss: 111.135651 Tokens per Sec: 66.572133 True Avg Loss: 108.235165
# Epoch Step: 81 Loss: 111.324035 Tokens per Sec: 66.116756 True Avg Loss: 108.651838
# Epoch Step: 86 Loss: 110.489570 Tokens per Sec: 66.986105 True Avg Loss: 107.822934
# Epoch Step: 91 Loss: 112.174229 Tokens per Sec: 66.232384 True Avg Loss: 109.874284
# Epoch Step: 96 Loss: 111.698016 Tokens per Sec: 66.133644 True Avg Loss: 109.480178
# Epoch Step: 1 Loss: 3.452762 Tokens per Sec: 122.501445 True Avg Loss: 345.276215
# Epoch Step: 6 Loss: 18.684027 Tokens per Sec: 122.363674 True Avg Loss: 319.324351
# val_avg_loss= 27.681402176815183
# val_true_avg_loss= 320.2673746744792
# val_diff_mean= 17.571524
# val_diff_std= 4.469567
# loss= 22.003102076872615
# Epoch= 14
# Epoch Step: 1 Loss: 112.893911 Tokens per Sec: 68.171799 True Avg Loss: 131.094772
# Epoch Step: 6 Loss: 113.654787 Tokens per Sec: 67.076278 True Avg Loss: 128.641258
# Epoch Step: 11 Loss: 115.453019 Tokens per Sec: 67.263570 True Avg Loss: 138.878682
# Epoch Step: 16 Loss: 115.022571 Tokens per Sec: 67.244469 True Avg Loss: 128.784175
# Epoch Step: 21 Loss: 114.871786 Tokens per Sec: 66.193644 True Avg Loss: 124.745043
# Epoch Step: 26 Loss: 113.609604 Tokens per Sec: 66.534934 True Avg Loss: 117.863189
# Epoch Step: 31 Loss: 113.592695 Tokens per Sec: 66.659035 True Avg Loss: 117.112862
# Epoch Step: 36 Loss: 113.308534 Tokens per Sec: 66.591792 True Avg Loss: 115.846811
# Epoch Step: 41 Loss: 113.054847 Tokens per Sec: 66.426307 True Avg Loss: 114.919606
# Epoch Step: 46 Loss: 112.638557 Tokens per Sec: 66.770365 True Avg Loss: 113.816702
# Epoch Step: 51 Loss: 112.306552 Tokens per Sec: 66.240059 True Avg Loss: 113.021628
# Epoch Step: 56 Loss: 112.228815 Tokens per Sec: 65.745358 True Avg Loss: 112.803203
# Epoch Step: 61 Loss: 111.798754 Tokens per Sec: 66.769023 True Avg Loss: 112.083019
# Epoch Step: 66 Loss: 111.715452 Tokens per Sec: 66.117081 True Avg Loss: 111.956967
# Epoch Step: 71 Loss: 112.547887 Tokens per Sec: 67.312282 True Avg Loss: 113.163127
# Epoch Step: 76 Loss: 113.272956 Tokens per Sec: 66.509533 True Avg Loss: 114.095092
# Epoch Step: 81 Loss: 112.105829 Tokens per Sec: 65.957121 True Avg Loss: 112.591754
# Epoch Step: 86 Loss: 112.536164 Tokens per Sec: 66.673208 True Avg Loss: 113.046886
# Epoch Step: 91 Loss: 111.999490 Tokens per Sec: 65.931071 True Avg Loss: 112.417749
# Epoch Step: 96 Loss: 111.954988 Tokens per Sec: 66.080194 True Avg Loss: 112.368818
# Epoch Step: 1 Loss: 3.098116 Tokens per Sec: 123.020861 True Avg Loss: 309.811584
# Epoch Step: 6 Loss: 17.287732 Tokens per Sec: 122.286035 True Avg Loss: 295.434987
# val_avg_loss= 25.51082872464572
# val_true_avg_loss= 295.1344502766927
# val_diff_mean= 16.916817
# val_diff_std= 3.8867548
# loss= 20.27641261442927
# Epoch= 15
# Epoch Step: 1 Loss: 111.030417 Tokens per Sec: 68.218576 True Avg Loss: 72.493233
# Epoch Step: 6 Loss: 110.801512 Tokens per Sec: 66.911382 True Avg Loss: 100.781667
# Epoch Step: 11 Loss: 110.145598 Tokens per Sec: 67.060647 True Avg Loss: 99.236351
# Epoch Step: 16 Loss: 109.140710 Tokens per Sec: 67.364553 True Avg Loss: 96.318037
# Epoch Step: 21 Loss: 109.496469 Tokens per Sec: 65.615084 True Avg Loss: 100.998690
# Epoch Step: 26 Loss: 108.559763 Tokens per Sec: 66.025621 True Avg Loss: 99.025556
# Epoch Step: 31 Loss: 107.642843 Tokens per Sec: 66.320342 True Avg Loss: 97.580769
# Epoch Step: 36 Loss: 108.230891 Tokens per Sec: 66.167903 True Avg Loss: 100.562530
# Epoch Step: 41 Loss: 108.669452 Tokens per Sec: 64.492481 True Avg Loss: 102.651742
# Epoch Step: 46 Loss: 108.679513 Tokens per Sec: 65.425952 True Avg Loss: 103.357252
# Epoch Step: 51 Loss: 109.148585 Tokens per Sec: 64.996907 True Avg Loss: 104.835916
# Epoch Step: 56 Loss: 109.044564 Tokens per Sec: 65.119300 True Avg Loss: 105.005079
# Epoch Step: 61 Loss: 108.644483 Tokens per Sec: 66.099563 True Avg Loss: 104.634250
# Epoch Step: 66 Loss: 108.278170 Tokens per Sec: 65.179841 True Avg Loss: 104.386702
# Epoch Step: 71 Loss: 107.619811 Tokens per Sec: 65.701820 True Avg Loss: 103.707373
# Epoch Step: 76 Loss: 107.542343 Tokens per Sec: 65.045491 True Avg Loss: 103.838207
# Epoch Step: 81 Loss: 107.525310 Tokens per Sec: 65.172460 True Avg Loss: 104.035787
# Epoch Step: 86 Loss: 108.461758 Tokens per Sec: 65.305098 True Avg Loss: 105.350816
# Epoch Step: 91 Loss: 109.050320 Tokens per Sec: 64.892186 True Avg Loss: 106.195414
# Epoch Step: 96 Loss: 109.430194 Tokens per Sec: 64.573850 True Avg Loss: 106.734740
# Epoch Step: 1 Loss: 2.780659 Tokens per Sec: 118.652847 True Avg Loss: 278.065887
# Epoch Step: 6 Loss: 14.902082 Tokens per Sec: 116.072849 True Avg Loss: 254.691386
# val_avg_loss= 21.991964209063095
# val_true_avg_loss= 254.43305460611978
# val_diff_mean= 15.756061
# val_diff_std= 3.288872
# loss= 17.48013352255785
# Epoch= 16
# Epoch Step: 1 Loss: 109.791279 Tokens per Sec: 65.736548 True Avg Loss: 76.917938
# Epoch Step: 6 Loss: 108.860686 Tokens per Sec: 66.143421 True Avg Loss: 88.408248
# Epoch Step: 11 Loss: 108.265300 Tokens per Sec: 65.474004 True Avg Loss: 92.206725
# Epoch Step: 16 Loss: 108.487852 Tokens per Sec: 64.844682 True Avg Loss: 98.617389
# Epoch Step: 21 Loss: 110.513780 Tokens per Sec: 64.990096 True Avg Loss: 110.848738
# Epoch Step: 26 Loss: 110.484913 Tokens per Sec: 65.134975 True Avg Loss: 110.645698
# Epoch Step: 31 Loss: 109.757157 Tokens per Sec: 65.079591 True Avg Loss: 108.273866
# Epoch Step: 36 Loss: 108.318227 Tokens per Sec: 65.273986 True Avg Loss: 104.391061
# Epoch Step: 41 Loss: 108.803999 Tokens per Sec: 65.154882 True Avg Loss: 106.074626
# Epoch Step: 46 Loss: 107.821200 Tokens per Sec: 64.738578 True Avg Loss: 104.211013
# Epoch Step: 51 Loss: 107.363652 Tokens per Sec: 65.137756 True Avg Loss: 103.664379
# Epoch Step: 56 Loss: 107.744863 Tokens per Sec: 65.976976 True Avg Loss: 104.667561
# Epoch Step: 61 Loss: 106.663679 Tokens per Sec: 67.201293 True Avg Loss: 103.127861
# Epoch Step: 66 Loss: 106.837963 Tokens per Sec: 66.370807 True Avg Loss: 103.647045
# Epoch Step: 71 Loss: 107.093329 Tokens per Sec: 67.031550 True Avg Loss: 104.215008
# Epoch Step: 76 Loss: 105.483635 Tokens per Sec: 66.125746 True Avg Loss: 102.254990
# Epoch Step: 81 Loss: 105.688279 Tokens per Sec: 66.155301 True Avg Loss: 102.719639
# Epoch Step: 86 Loss: 107.729430 Tokens per Sec: 67.111642 True Avg Loss: 105.318434
# Epoch Step: 91 Loss: 107.144223 Tokens per Sec: 65.777927 True Avg Loss: 104.813398
# Epoch Step: 96 Loss: 107.064825 Tokens per Sec: 66.361724 True Avg Loss: 104.862799
# Epoch Step: 1 Loss: 2.964747 Tokens per Sec: 118.042381 True Avg Loss: 296.474670
# Epoch Step: 6 Loss: 16.366954 Tokens per Sec: 122.466839 True Avg Loss: 279.752246
# val_avg_loss= 24.00091376481304
# val_true_avg_loss= 277.73267449273004
# val_diff_mean= 16.48523
# val_diff_std= 3.308991
# loss= 19.08087076667611
# Epoch= 17
# Epoch Step: 1 Loss: 105.212475 Tokens per Sec: 67.902715 True Avg Loss: 98.785736
# Epoch Step: 6 Loss: 105.044249 Tokens per Sec: 67.150417 True Avg Loss: 101.118393
# Epoch Step: 11 Loss: 106.219989 Tokens per Sec: 66.224790 True Avg Loss: 113.736151
# Epoch Step: 16 Loss: 107.931287 Tokens per Sec: 67.437487 True Avg Loss: 122.251644
# Epoch Step: 21 Loss: 107.447915 Tokens per Sec: 65.843884 True Avg Loss: 116.509431
# Epoch Step: 26 Loss: 109.001015 Tokens per Sec: 66.550796 True Avg Loss: 120.801222
# Epoch Step: 31 Loss: 107.132539 Tokens per Sec: 65.338771 True Avg Loss: 112.749150
# Epoch Step: 36 Loss: 106.670918 Tokens per Sec: 64.720022 True Avg Loss: 110.667259
# Epoch Step: 41 Loss: 107.147012 Tokens per Sec: 64.586453 True Avg Loss: 111.299368
# Epoch Step: 46 Loss: 107.168952 Tokens per Sec: 65.156350 True Avg Loss: 110.920294
# Epoch Step: 51 Loss: 107.128948 Tokens per Sec: 65.192834 True Avg Loss: 110.456378
# Epoch Step: 56 Loss: 106.865274 Tokens per Sec: 65.544833 True Avg Loss: 109.650931
# Epoch Step: 61 Loss: 106.194248 Tokens per Sec: 67.388459 True Avg Loss: 108.318662
# Epoch Step: 66 Loss: 105.540245 Tokens per Sec: 66.638728 True Avg Loss: 107.148342
# Epoch Step: 71 Loss: 105.283358 Tokens per Sec: 67.215427 True Avg Loss: 106.681006
# Epoch Step: 76 Loss: 105.563545 Tokens per Sec: 66.067937 True Avg Loss: 106.954857
# Epoch Step: 81 Loss: 106.351560 Tokens per Sec: 65.801558 True Avg Loss: 107.854393
# Epoch Step: 86 Loss: 106.787084 Tokens per Sec: 66.579887 True Avg Loss: 108.281986
# Epoch Step: 91 Loss: 106.209261 Tokens per Sec: 66.480477 True Avg Loss: 107.526652
# Epoch Step: 96 Loss: 105.114758 Tokens per Sec: 65.893821 True Avg Loss: 106.283017
# Epoch Step: 1 Loss: 3.101978 Tokens per Sec: 123.872858 True Avg Loss: 310.197845
# Epoch Step: 6 Loss: 16.927876 Tokens per Sec: 121.843409 True Avg Loss: 289.305155
# val_avg_loss= 24.481021087401
# val_true_avg_loss= 283.4010297987196
# val_diff_mean= 16.668442
# val_diff_std= 3.5762768
# loss= 19.470299757163943
# Epoch= 18
# Epoch Step: 1 Loss: 105.226542 Tokens per Sec: 67.946853 True Avg Loss: 93.390152
# Epoch Step: 6 Loss: 105.130900 Tokens per Sec: 67.260685 True Avg Loss: 101.598725
# Epoch Step: 11 Loss: 104.563849 Tokens per Sec: 67.126894 True Avg Loss: 98.015914
# Epoch Step: 16 Loss: 105.074753 Tokens per Sec: 67.107428 True Avg Loss: 103.313830
# Epoch Step: 21 Loss: 106.549643 Tokens per Sec: 66.005399 True Avg Loss: 110.874852
# Epoch Step: 26 Loss: 106.625907 Tokens per Sec: 66.486089 True Avg Loss: 110.331988
# Epoch Step: 31 Loss: 106.989874 Tokens per Sec: 66.269050 True Avg Loss: 110.944880
# Epoch Step: 36 Loss: 106.092415 Tokens per Sec: 66.308166 True Avg Loss: 107.845087
# Epoch Step: 41 Loss: 106.076591 Tokens per Sec: 66.401318 True Avg Loss: 107.562865
# Epoch Step: 46 Loss: 106.141263 Tokens per Sec: 66.785396 True Avg Loss: 107.539496
# Epoch Step: 51 Loss: 105.518437 Tokens per Sec: 66.010463 True Avg Loss: 106.147433
# Epoch Step: 56 Loss: 104.225807 Tokens per Sec: 65.985189 True Avg Loss: 103.723228
# Epoch Step: 61 Loss: 103.161926 Tokens per Sec: 66.794649 True Avg Loss: 101.950751
# Epoch Step: 66 Loss: 104.754953 Tokens per Sec: 66.112808 True Avg Loss: 104.548383
# Epoch Step: 71 Loss: 105.398784 Tokens per Sec: 66.434159 True Avg Loss: 105.547822
# Epoch Step: 76 Loss: 105.327698 Tokens per Sec: 65.938949 True Avg Loss: 105.412778
# Epoch Step: 81 Loss: 104.898550 Tokens per Sec: 66.149824 True Avg Loss: 104.867629
# Epoch Step: 86 Loss: 104.587350 Tokens per Sec: 66.547087 True Avg Loss: 104.490126
# Epoch Step: 91 Loss: 102.611797 Tokens per Sec: 66.194846 True Avg Loss: 102.270110
# Epoch Step: 96 Loss: 102.394415 Tokens per Sec: 66.258110 True Avg Loss: 102.083615
# Epoch Step: 1 Loss: 3.383988 Tokens per Sec: 120.949343 True Avg Loss: 338.398773
# Epoch Step: 6 Loss: 19.130159 Tokens per Sec: 120.925544 True Avg Loss: 326.877248
# val_avg_loss= 27.843057789487084
# val_true_avg_loss= 322.18928697374133
# val_diff_mean= 17.78876
# val_diff_std= 3.4516964
# loss= 22.1351418531578
# Epoch= 19
# Epoch Step: 1 Loss: 102.675526 Tokens per Sec: 68.016476 True Avg Loss: 164.474716
# Epoch Step: 6 Loss: 102.592601 Tokens per Sec: 66.923619 True Avg Loss: 111.151937
# Epoch Step: 11 Loss: 103.809243 Tokens per Sec: 66.939560 True Avg Loss: 118.753590
# Epoch Step: 16 Loss: 103.861669 Tokens per Sec: 67.043858 True Avg Loss: 114.393721
# Epoch Step: 21 Loss: 104.182208 Tokens per Sec: 66.088706 True Avg Loss: 113.380571
# Epoch Step: 26 Loss: 103.710397 Tokens per Sec: 66.289028 True Avg Loss: 109.749464
# Epoch Step: 31 Loss: 103.973516 Tokens per Sec: 66.200161 True Avg Loss: 109.618252
# Epoch Step: 36 Loss: 103.750768 Tokens per Sec: 66.009736 True Avg Loss: 108.174930
# Epoch Step: 41 Loss: 104.773434 Tokens per Sec: 65.568605 True Avg Loss: 110.181737
# Epoch Step: 46 Loss: 104.386661 Tokens per Sec: 66.172836 True Avg Loss: 108.741941
# Epoch Step: 51 Loss: 103.440107 Tokens per Sec: 66.038941 True Avg Loss: 106.422776
# Epoch Step: 56 Loss: 104.501504 Tokens per Sec: 66.058481 True Avg Loss: 108.122842
# Epoch Step: 61 Loss: 103.408658 Tokens per Sec: 66.929239 True Avg Loss: 105.989192
# Epoch Step: 66 Loss: 102.959686 Tokens per Sec: 66.481268 True Avg Loss: 105.101719
# Epoch Step: 71 Loss: 102.346273 Tokens per Sec: 67.254092 True Avg Loss: 104.072014
# Epoch Step: 76 Loss: 101.021862 Tokens per Sec: 65.923973 True Avg Loss: 102.185321
# Epoch Step: 81 Loss: 101.604593 Tokens per Sec: 65.697665 True Avg Loss: 102.849405
# Epoch Step: 86 Loss: 101.285089 Tokens per Sec: 66.857600 True Avg Loss: 102.399919
# Epoch Step: 91 Loss: 103.354682 Tokens per Sec: 66.499595 True Avg Loss: 104.659369
# Epoch Step: 96 Loss: 103.787344 Tokens per Sec: 65.861668 True Avg Loss: 105.077453
# Epoch Step: 1 Loss: 3.265310 Tokens per Sec: 123.080878 True Avg Loss: 326.530975
# Epoch Step: 6 Loss: 18.078655 Tokens per Sec: 122.298738 True Avg Loss: 308.905838
# val_avg_loss= 26.50518199502305
# val_true_avg_loss= 306.62537638346356
# val_diff_mean= 17.352024
# val_diff_std= 3.1615732
# loss= 21.06586555306238
# Epoch= 20
# Epoch Step: 1 Loss: 103.502034 Tokens per Sec: 67.982576 True Avg Loss: 114.535004
# Epoch Step: 6 Loss: 104.021441 Tokens per Sec: 67.374698 True Avg Loss: 114.547540
# Epoch Step: 11 Loss: 103.182341 Tokens per Sec: 67.203756 True Avg Loss: 101.697918
# Epoch Step: 16 Loss: 103.000248 Tokens per Sec: 67.332826 True Avg Loss: 100.943860
# Epoch Step: 21 Loss: 101.870394 Tokens per Sec: 66.215289 True Avg Loss: 95.961826
# Epoch Step: 26 Loss: 102.268984 Tokens per Sec: 66.484600 True Avg Loss: 98.695164
# Epoch Step: 31 Loss: 103.089519 Tokens per Sec: 66.591673 True Avg Loss: 101.974528
# Epoch Step: 36 Loss: 102.071036 Tokens per Sec: 66.498554 True Avg Loss: 99.215215
# Epoch Step: 41 Loss: 104.013500 Tokens per Sec: 66.266471 True Avg Loss: 104.386161
# Epoch Step: 46 Loss: 105.613283 Tokens per Sec: 66.869325 True Avg Loss: 107.898276
# Epoch Step: 51 Loss: 105.195841 Tokens per Sec: 66.201349 True Avg Loss: 106.814503
# Epoch Step: 56 Loss: 104.786285 Tokens per Sec: 66.143421 True Avg Loss: 105.914192
# Epoch Step: 61 Loss: 104.759654 Tokens per Sec: 67.237112 True Avg Loss: 105.764505
# Epoch Step: 66 Loss: 104.899301 Tokens per Sec: 65.946232 True Avg Loss: 105.902598
# Epoch Step: 71 Loss: 104.409508 Tokens per Sec: 67.366555 True Avg Loss: 105.162035
# Epoch Step: 76 Loss: 104.322426 Tokens per Sec: 66.603424 True Avg Loss: 104.992100
# Epoch Step: 81 Loss: 104.298273 Tokens per Sec: 66.194715 True Avg Loss: 104.882816
# Epoch Step: 86 Loss: 103.355294 Tokens per Sec: 62.429568 True Avg Loss: 103.726128
# Epoch Step: 91 Loss: 104.274261 Tokens per Sec: 62.559091 True Avg Loss: 104.739069
# Epoch Step: 96 Loss: 103.963463 Tokens per Sec: 61.968720 True Avg Loss: 104.382101
# Epoch Step: 1 Loss: 2.990660 Tokens per Sec: 100.414569 True Avg Loss: 299.065979
# Epoch Step: 6 Loss: 16.563289 Tokens per Sec: 120.196860 True Avg Loss: 282.991506
# val_avg_loss= 24.221008157334644
# val_true_avg_loss= 280.2161373562283
# val_diff_mean= 16.636578
# val_diff_std= 2.8537393
# loss= 19.251490352717976
# Epoch= 21
# Epoch Step: 1 Loss: 104.494405 Tokens per Sec: 67.373507 True Avg Loss: 181.410797
# Epoch Step: 6 Loss: 104.251532 Tokens per Sec: 65.404820 True Avg Loss: 113.086959
# Epoch Step: 11 Loss: 102.930099 Tokens per Sec: 64.581742 True Avg Loss: 96.706541
# Epoch Step: 16 Loss: 103.101886 Tokens per Sec: 57.961356 True Avg Loss: 99.852954
# Epoch Step: 21 Loss: 102.961334 Tokens per Sec: 58.376235 True Avg Loss: 99.992925
# Epoch Step: 26 Loss: 102.946607 Tokens per Sec: 61.451222 True Avg Loss: 100.523977
# Epoch Step: 31 Loss: 102.427047 Tokens per Sec: 64.532370 True Avg Loss: 99.181057
# Epoch Step: 36 Loss: 103.025069 Tokens per Sec: 63.179824 True Avg Loss: 101.321264
# Epoch Step: 41 Loss: 102.639333 Tokens per Sec: 64.164546 True Avg Loss: 100.567187
# Epoch Step: 46 Loss: 101.477876 Tokens per Sec: 63.921240 True Avg Loss: 98.195131
# Epoch Step: 51 Loss: 101.553935 Tokens per Sec: 64.043645 True Avg Loss: 98.636008
# Epoch Step: 56 Loss: 101.508670 Tokens per Sec: 63.085688 True Avg Loss: 98.780994
# Epoch Step: 61 Loss: 100.972607 Tokens per Sec: 65.964460 True Avg Loss: 98.103625
# Epoch Step: 66 Loss: 100.343310 Tokens per Sec: 62.797196 True Avg Loss: 97.343563
# Epoch Step: 71 Loss: 99.887870 Tokens per Sec: 65.801287 True Avg Loss: 96.912247
# Epoch Step: 76 Loss: 99.872078 Tokens per Sec: 64.875123 True Avg Loss: 97.054363
# Epoch Step: 81 Loss: 98.923741 Tokens per Sec: 63.134069 True Avg Loss: 96.027433
# Epoch Step: 86 Loss: 98.827297 Tokens per Sec: 62.427257 True Avg Loss: 96.088031
# Epoch Step: 91 Loss: 98.708569 Tokens per Sec: 64.781360 True Avg Loss: 96.104958
# Epoch Step: 96 Loss: 100.223301 Tokens per Sec: 64.369899 True Avg Loss: 97.832421
# Epoch Step: 1 Loss: 3.356906 Tokens per Sec: 117.457896 True Avg Loss: 335.690582
# Epoch Step: 6 Loss: 18.410762 Tokens per Sec: 110.956681 True Avg Loss: 314.600596
# val_avg_loss= 27.104802447454666
# val_true_avg_loss= 313.5609775119358
# val_diff_mean= 17.57274
# val_diff_std= 3.2483103
# loss= 21.54235723364444
# Epoch= 22
# Epoch Step: 1 Loss: 99.206767 Tokens per Sec: 66.424887 True Avg Loss: 93.415848
# Epoch Step: 6 Loss: 98.378638 Tokens per Sec: 60.400180 True Avg Loss: 84.034214
# Epoch Step: 11 Loss: 98.853704 Tokens per Sec: 60.530429 True Avg Loss: 94.887322
# Epoch Step: 16 Loss: 97.947674 Tokens per Sec: 62.578517 True Avg Loss: 90.324426
# Epoch Step: 21 Loss: 98.594229 Tokens per Sec: 59.152926 True Avg Loss: 95.258842
# Epoch Step: 26 Loss: 99.383788 Tokens per Sec: 59.617528 True Avg Loss: 98.958428
# Epoch Step: 31 Loss: 99.080455 Tokens per Sec: 60.677378 True Avg Loss: 98.037553
# Epoch Step: 36 Loss: 98.114658 Tokens per Sec: 65.000999 True Avg Loss: 95.418858
# Epoch Step: 41 Loss: 98.156114 Tokens per Sec: 63.973241 True Avg Loss: 95.826963
# Epoch Step: 46 Loss: 99.008540 Tokens per Sec: 63.415423 True Avg Loss: 97.970821
# Epoch Step: 51 Loss: 99.757306 Tokens per Sec: 63.761476 True Avg Loss: 99.559221
# Epoch Step: 56 Loss: 99.344262 Tokens per Sec: 63.901921 True Avg Loss: 98.811142
# Epoch Step: 61 Loss: 98.672069 Tokens per Sec: 65.494963 True Avg Loss: 97.761903
# Epoch Step: 66 Loss: 98.280825 Tokens per Sec: 65.353953 True Avg Loss: 97.238527
# Epoch Step: 71 Loss: 97.519095 Tokens per Sec: 65.324677 True Avg Loss: 96.210407
# Epoch Step: 76 Loss: 96.934908 Tokens per Sec: 64.167785 True Avg Loss: 95.514725
# Epoch Step: 81 Loss: 97.426286 Tokens per Sec: 63.013018 True Avg Loss: 96.235153
# Epoch Step: 86 Loss: 96.758317 Tokens per Sec: 64.583370 True Avg Loss: 95.497287
# Epoch Step: 91 Loss: 96.434157 Tokens per Sec: 64.407164 True Avg Loss: 95.212685
# Epoch Step: 96 Loss: 96.999181 Tokens per Sec: 61.613913 True Avg Loss: 95.883063
# Epoch Step: 1 Loss: 2.110136 Tokens per Sec: 108.179383 True Avg Loss: 211.013596
# Epoch Step: 6 Loss: 12.018361 Tokens per Sec: 107.460288 True Avg Loss: 205.346881
# val_avg_loss= 18.270550768784958
# ...
# Epoch Step: 1 Loss: 1.566271 Tokens per Sec: 104.997871 True Avg Loss: 156.627136
# Epoch Step: 6 Loss: 8.974729 Tokens per Sec: 102.915551 True Avg Loss: 153.469546
# val_avg_loss= 13.209593638235962
# val_true_avg_loss= 152.87512715657553
# val_diff_mean= 12.210274
# val_diff_std= 2.3713515
# loss= 10.502871331367784
# Epoch= 91
# Epoch Step: 1 Loss: 65.773631 Tokens per Sec: 61.274659 True Avg Loss: 67.635437
# Epoch Step: 6 Loss: 66.530110 Tokens per Sec: 59.920266 True Avg Loss: 78.777802
# Epoch Step: 11 Loss: 66.810480 Tokens per Sec: 59.179540 True Avg Loss: 75.758396
# Epoch Step: 16 Loss: 66.528140 Tokens per Sec: 60.226299 True Avg Loss: 71.199364
# Epoch Step: 21 Loss: 66.189719 Tokens per Sec: 58.507797 True Avg Loss: 68.448127
# Epoch Step: 26 Loss: 66.672819 Tokens per Sec: 59.093566 True Avg Loss: 69.876823
# Epoch Step: 31 Loss: 65.766060 Tokens per Sec: 57.427053 True Avg Loss: 66.390620
# Epoch Step: 36 Loss: 64.786673 Tokens per Sec: 59.350979 True Avg Loss: 63.506979
# Epoch Step: 41 Loss: 64.371829 Tokens per Sec: 58.824576 True Avg Loss: 62.618045
# Epoch Step: 46 Loss: 64.487578 Tokens per Sec: 60.928541 True Avg Loss: 63.072422
# Epoch Step: 51 Loss: 64.047969 Tokens per Sec: 59.404924 True Avg Loss: 62.340204
# Epoch Step: 56 Loss: 63.832367 Tokens per Sec: 59.070388 True Avg Loss: 62.102955
# Epoch Step: 61 Loss: 63.681196 Tokens per Sec: 58.771689 True Avg Loss: 62.006462
# Epoch Step: 66 Loss: 63.694836 Tokens per Sec: 58.880079 True Avg Loss: 62.153464
# Epoch Step: 71 Loss: 63.345654 Tokens per Sec: 59.472964 True Avg Loss: 61.773898
# Epoch Step: 76 Loss: 64.478142 Tokens per Sec: 57.790902 True Avg Loss: 63.387989
# Epoch Step: 81 Loss: 64.523483 Tokens per Sec: 52.304446 True Avg Loss: 63.517290
# Epoch Step: 86 Loss: 64.299727 Tokens per Sec: 54.776289 True Avg Loss: 63.306935
# Epoch Step: 91 Loss: 63.756740 Tokens per Sec: 53.078976 True Avg Loss: 62.758606
# Epoch Step: 96 Loss: 63.312288 Tokens per Sec: 51.143531 True Avg Loss: 62.349412
# Epoch Step: 1 Loss: 1.666446 Tokens per Sec: 108.848425 True Avg Loss: 166.644562
# Epoch Step: 6 Loss: 9.826782 Tokens per Sec: 105.146062 True Avg Loss: 167.993780
# val_avg_loss= 14.682590506688
# val_true_avg_loss= 169.81224229600696
# val_diff_mean= 12.8321085
# val_diff_std= 2.5579994
# loss= 11.666489928733302
# Epoch= 92
# Epoch Step: 1 Loss: 63.574433 Tokens per Sec: 54.840541 True Avg Loss: 63.919090
# Epoch Step: 6 Loss: 63.937820 Tokens per Sec: 54.402206 True Avg Loss: 69.704562
# Epoch Step: 11 Loss: 64.431890 Tokens per Sec: 58.941432 True Avg Loss: 71.617235
# Epoch Step: 16 Loss: 63.952428 Tokens per Sec: 56.883160 True Avg Loss: 66.332268
# Epoch Step: 21 Loss: 64.089777 Tokens per Sec: 57.693355 True Avg Loss: 66.462250
# Epoch Step: 26 Loss: 65.319184 Tokens per Sec: 60.453698 True Avg Loss: 70.832825
# Epoch Step: 31 Loss: 65.872379 Tokens per Sec: 60.040017 True Avg Loss: 71.753964
# Epoch Step: 36 Loss: 65.667365 Tokens per Sec: 58.668938 True Avg Loss: 70.326820
# Epoch Step: 41 Loss: 65.680591 Tokens per Sec: 59.218444 True Avg Loss: 69.790323
# Epoch Step: 46 Loss: 65.736498 Tokens per Sec: 61.415219 True Avg Loss: 69.465187
# Epoch Step: 51 Loss: 65.267321 Tokens per Sec: 58.458686 True Avg Loss: 68.160239
# Epoch Step: 56 Loss: 64.546819 Tokens per Sec: 59.301962 True Avg Loss: 66.595190
# Epoch Step: 61 Loss: 64.326342 Tokens per Sec: 59.754368 True Avg Loss: 66.071967
# Epoch Step: 66 Loss: 64.930154 Tokens per Sec: 61.892890 True Avg Loss: 66.897667
# Epoch Step: 71 Loss: 64.733904 Tokens per Sec: 61.747558 True Avg Loss: 66.488915
# Epoch Step: 76 Loss: 64.222988 Tokens per Sec: 63.393402 True Avg Loss: 65.679662
# Epoch Step: 81 Loss: 64.269329 Tokens per Sec: 63.741841 True Avg Loss: 65.657207
# Epoch Step: 86 Loss: 65.425281 Tokens per Sec: 62.932429 True Avg Loss: 66.942902
# Epoch Step: 91 Loss: 65.808384 Tokens per Sec: 63.757405 True Avg Loss: 67.296596
# Epoch Step: 96 Loss: 65.276238 Tokens per Sec: 62.803425 True Avg Loss: 66.657120
# Epoch Step: 1 Loss: 1.980259 Tokens per Sec: 64.232347 True Avg Loss: 198.025879
# Epoch Step: 6 Loss: 11.279827 Tokens per Sec: 89.862787 True Avg Loss: 192.868889
# val_avg_loss= 16.6989743402653
# val_true_avg_loss= 193.2117445203993
# val_diff_mean= 13.778256
# val_diff_std= 2.372556
# loss= 13.274089318195372
# Epoch= 93
# Epoch Step: 1 Loss: 65.142102 Tokens per Sec: 58.131702 True Avg Loss: 60.130238
# Epoch Step: 6 Loss: 65.153300 Tokens per Sec: 59.691396 True Avg Loss: 64.631467
# Epoch Step: 11 Loss: 64.801727 Tokens per Sec: 62.524551 True Avg Loss: 61.607909
# Epoch Step: 16 Loss: 64.537047 Tokens per Sec: 61.566545 True Avg Loss: 60.904110
# Epoch Step: 21 Loss: 64.669111 Tokens per Sec: 61.367673 True Avg Loss: 62.418682
# Epoch Step: 26 Loss: 64.420606 Tokens per Sec: 63.718335 True Avg Loss: 61.835946
# Epoch Step: 31 Loss: 64.648483 Tokens per Sec: 61.215802 True Avg Loss: 63.045758
# Epoch Step: 36 Loss: 65.103781 Tokens per Sec: 59.493051 True Avg Loss: 64.584548
# Epoch Step: 41 Loss: 64.829915 Tokens per Sec: 59.452763 True Avg Loss: 63.937948
# Epoch Step: 46 Loss: 64.318137 Tokens per Sec: 58.676787 True Avg Loss: 62.906718
# Epoch Step: 51 Loss: 64.651557 Tokens per Sec: 56.757730 True Avg Loss: 63.723726
# Epoch Step: 56 Loss: 64.985013 Tokens per Sec: 57.344907 True Avg Loss: 64.424029
# Epoch Step: 61 Loss: 64.390439 Tokens per Sec: 58.825359 True Avg Loss: 63.470413
# Epoch Step: 66 Loss: 63.515968 Tokens per Sec: 57.742758 True Avg Loss: 62.195657
# Epoch Step: 71 Loss: 62.577977 Tokens per Sec: 59.617475 True Avg Loss: 60.939012
# Epoch Step: 76 Loss: 62.503054 Tokens per Sec: 59.140279 True Avg Loss: 60.943407
# Epoch Step: 81 Loss: 62.585810 Tokens per Sec: 60.701647 True Avg Loss: 61.136993
# Epoch Step: 86 Loss: 63.312079 Tokens per Sec: 63.197983 True Avg Loss: 62.077986
# Epoch Step: 91 Loss: 63.589632 Tokens per Sec: 63.645118 True Avg Loss: 62.458128
# Epoch Step: 96 Loss: 64.399485 Tokens per Sec: 63.461407 True Avg Loss: 63.361534
# Epoch Step: 1 Loss: 2.259561 Tokens per Sec: 117.577048 True Avg Loss: 225.956085
# Epoch Step: 6 Loss: 12.999866 Tokens per Sec: 114.780991 True Avg Loss: 222.274521
# val_avg_loss= 19.3012296595874
# val_true_avg_loss= 223.27851019965277
# val_diff_mean= 14.806436
# val_diff_std= 2.3529398
# loss= 15.339744975548664
# Epoch= 94
# Epoch Step: 1 Loss: 63.277779 Tokens per Sec: 66.255362 True Avg Loss: 32.547390
# Epoch Step: 6 Loss: 63.718433 Tokens per Sec: 63.778952 True Avg Loss: 65.676701
# Epoch Step: 11 Loss: 63.462184 Tokens per Sec: 64.898938 True Avg Loss: 62.495310
# Epoch Step: 16 Loss: 62.847292 Tokens per Sec: 65.405865 True Avg Loss: 58.892562
# Epoch Step: 21 Loss: 62.474846 Tokens per Sec: 64.369911 True Avg Loss: 58.058005
# Epoch Step: 26 Loss: 62.560286 Tokens per Sec: 64.600641 True Avg Loss: 59.223942
# Epoch Step: 31 Loss: 63.552445 Tokens per Sec: 64.800689 True Avg Loss: 63.007990
# Epoch Step: 36 Loss: 63.746649 Tokens per Sec: 64.971723 True Avg Loss: 63.660519
# Epoch Step: 41 Loss: 64.197835 Tokens per Sec: 64.612110 True Avg Loss: 64.831018
# Epoch Step: 46 Loss: 64.021513 Tokens per Sec: 64.991682 True Avg Loss: 64.359305
# Epoch Step: 51 Loss: 64.091764 Tokens per Sec: 64.562357 True Avg Loss: 64.503748
# Epoch Step: 56 Loss: 64.654395 Tokens per Sec: 62.455655 True Avg Loss: 65.466705
# Epoch Step: 61 Loss: 64.379709 Tokens per Sec: 64.923098 True Avg Loss: 64.943224
# Epoch Step: 66 Loss: 64.239016 Tokens per Sec: 63.102214 True Avg Loss: 64.695673
# Epoch Step: 71 Loss: 65.084644 Tokens per Sec: 64.243538 True Avg Loss: 65.887149
# Epoch Step: 76 Loss: 64.835166 Tokens per Sec: 63.244189 True Avg Loss: 65.503329
# Epoch Step: 81 Loss: 65.309353 Tokens per Sec: 62.775039 True Avg Loss: 66.062404
# Epoch Step: 86 Loss: 65.283396 Tokens per Sec: 63.912741 True Avg Loss: 65.986344
# Epoch Step: 91 Loss: 65.096598 Tokens per Sec: 63.416526 True Avg Loss: 65.746549
# Epoch Step: 96 Loss: 64.763755 Tokens per Sec: 63.126729 True Avg Loss: 65.368289
# Epoch Step: 1 Loss: 2.476422 Tokens per Sec: 115.269101 True Avg Loss: 247.642212
# Epoch Step: 6 Loss: 14.229625 Tokens per Sec: 111.968921 True Avg Loss: 243.296209
# val_avg_loss= 21.18751510898756
# val_true_avg_loss= 245.07686699761285
# val_diff_mean= 15.52308
# val_diff_std= 2.4114685
# loss= 16.837342007469584
# Epoch= 95
# Epoch Step: 1 Loss: 65.982047 Tokens per Sec: 65.159171 True Avg Loss: 132.109985
# Epoch Step: 6 Loss: 65.003978 Tokens per Sec: 64.646704 True Avg Loss: 60.313258
# Epoch Step: 11 Loss: 65.301029 Tokens per Sec: 63.875073 True Avg Loss: 65.248737
# Epoch Step: 16 Loss: 65.346509 Tokens per Sec: 63.941618 True Avg Loss: 65.525589
# Epoch Step: 21 Loss: 65.113286 Tokens per Sec: 62.617101 True Avg Loss: 64.423141
# Epoch Step: 26 Loss: 64.526978 Tokens per Sec: 63.802867 True Avg Loss: 62.268658
# Epoch Step: 31 Loss: 64.650132 Tokens per Sec: 63.574298 True Avg Loss: 63.070037
# Epoch Step: 36 Loss: 64.877600 Tokens per Sec: 63.294485 True Avg Loss: 63.947882
# Epoch Step: 41 Loss: 64.791469 Tokens per Sec: 61.555420 True Avg Loss: 63.842313
# Epoch Step: 46 Loss: 64.943311 Tokens per Sec: 63.192461 True Avg Loss: 64.291456
# Epoch Step: 51 Loss: 64.293815 Tokens per Sec: 62.410850 True Avg Loss: 63.064160
# Epoch Step: 56 Loss: 64.276795 Tokens per Sec: 60.232234 True Avg Loss: 63.151435
# Epoch Step: 61 Loss: 64.622650 Tokens per Sec: 63.559330 True Avg Loss: 63.809292
# Epoch Step: 66 Loss: 64.258645 Tokens per Sec: 63.376567 True Avg Loss: 63.310933
# Epoch Step: 71 Loss: 63.759188 Tokens per Sec: 64.692833 True Avg Loss: 62.657165
# Epoch Step: 76 Loss: 65.098507 Tokens per Sec: 62.782673 True Avg Loss: 64.504579
# Epoch Step: 81 Loss: 65.411080 Tokens per Sec: 62.432135 True Avg Loss: 64.938451
# Epoch Step: 86 Loss: 65.877276 Tokens per Sec: 62.489305 True Avg Loss: 65.518447
# Epoch Step: 91 Loss: 66.440944 Tokens per Sec: 59.439504 True Avg Loss: 66.173476
# Epoch Step: 96 Loss: 65.663518 Tokens per Sec: 55.842412 True Avg Loss: 65.361661
# Epoch Step: 1 Loss: 1.650063 Tokens per Sec: 109.485590 True Avg Loss: 165.006332
# Epoch Step: 6 Loss: 9.312706 Tokens per Sec: 110.113236 True Avg Loss: 159.275386
# val_avg_loss= 13.85402323248377
# val_true_avg_loss= 160.28667195638022
# val_diff_mean= 12.441448
# val_diff_std= 2.5496652
# loss= 11.012061432117724
# Epoch= 96
# Epoch Step: 1 Loss: 65.562165 Tokens per Sec: 58.475638 True Avg Loss: 96.427628
# Epoch Step: 6 Loss: 65.899953 Tokens per Sec: 62.319498 True Avg Loss: 76.316668
# Epoch Step: 11 Loss: 66.061666 Tokens per Sec: 58.979589 True Avg Loss: 73.161229
# Epoch Step: 16 Loss: 65.298635 Tokens per Sec: 58.489531 True Avg Loss: 66.086992
# Epoch Step: 21 Loss: 65.850687 Tokens per Sec: 61.432220 True Avg Loss: 68.537408
# Epoch Step: 26 Loss: 65.410571 Tokens per Sec: 64.328274 True Avg Loss: 66.304442
# Epoch Step: 31 Loss: 65.085880 Tokens per Sec: 64.412295 True Avg Loss: 65.083236
# Epoch Step: 36 Loss: 64.578415 Tokens per Sec: 64.539272 True Avg Loss: 63.652850
# Epoch Step: 41 Loss: 64.685751 Tokens per Sec: 64.302608 True Avg Loss: 64.020394
# Epoch Step: 46 Loss: 63.775430 Tokens per Sec: 64.935398 True Avg Loss: 62.066698
# Epoch Step: 51 Loss: 63.978609 Tokens per Sec: 60.628064 True Avg Loss: 62.626034
# Epoch Step: 56 Loss: 64.166402 Tokens per Sec: 59.753581 True Avg Loss: 63.067736
# Epoch Step: 61 Loss: 63.873122 Tokens per Sec: 61.058059 True Avg Loss: 62.681266
# Epoch Step: 66 Loss: 63.984779 Tokens per Sec: 61.689707 True Avg Loss: 62.950914
# Epoch Step: 71 Loss: 64.773059 Tokens per Sec: 59.605032 True Avg Loss: 64.175088
# Epoch Step: 76 Loss: 64.287011 Tokens per Sec: 63.679482 True Avg Loss: 63.562342
# Epoch Step: 81 Loss: 64.678161 Tokens per Sec: 63.614446 True Avg Loss: 64.104444
# Epoch Step: 86 Loss: 64.367652 Tokens per Sec: 63.993262 True Avg Loss: 63.775136
# Epoch Step: 91 Loss: 64.420539 Tokens per Sec: 64.789654 True Avg Loss: 63.872606
# Epoch Step: 96 Loss: 63.779483 Tokens per Sec: 61.215545 True Avg Loss: 63.224493
# Epoch Step: 1 Loss: 1.794696 Tokens per Sec: 106.729706 True Avg Loss: 179.469635
# Epoch Step: 6 Loss: 10.601028 Tokens per Sec: 97.716224 True Avg Loss: 181.254138
# val_avg_loss= 15.911278673902933
# val_true_avg_loss= 183.99800788031683
# val_diff_mean= 13.359223
# val_diff_std= 2.4833515
# loss= 12.641084510861463
# Epoch= 97
# Epoch Step: 1 Loss: 63.832918 Tokens per Sec: 62.186435 True Avg Loss: 110.771164
# Epoch Step: 6 Loss: 64.097426 Tokens per Sec: 63.256553 True Avg Loss: 75.907973
# Epoch Step: 11 Loss: 63.532907 Tokens per Sec: 65.453506 True Avg Loss: 65.306832
# Epoch Step: 16 Loss: 63.527187 Tokens per Sec: 64.806634 True Avg Loss: 64.683547
# Epoch Step: 21 Loss: 64.171658 Tokens per Sec: 62.742160 True Avg Loss: 67.506942
# Epoch Step: 26 Loss: 64.040208 Tokens per Sec: 60.049827 True Avg Loss: 66.291811
# Epoch Step: 31 Loss: 64.565137 Tokens per Sec: 58.947189 True Avg Loss: 67.678052
# Epoch Step: 36 Loss: 64.467861 Tokens per Sec: 60.071984 True Avg Loss: 66.963073
# Epoch Step: 41 Loss: 64.992694 Tokens per Sec: 61.810436 True Avg Loss: 67.951044
# Epoch Step: 46 Loss: 64.124423 Tokens per Sec: 60.731982 True Avg Loss: 65.708402
# Epoch Step: 51 Loss: 64.577230 Tokens per Sec: 63.854652 True Avg Loss: 66.425814
# Epoch Step: 56 Loss: 64.539831 Tokens per Sec: 63.415459 True Avg Loss: 66.212462
# Epoch Step: 61 Loss: 64.516363 Tokens per Sec: 62.992446 True Avg Loss: 66.027088
# Epoch Step: 66 Loss: 65.159048 Tokens per Sec: 61.919148 True Avg Loss: 66.890297
# Epoch Step: 71 Loss: 64.984705 Tokens per Sec: 65.108332 True Avg Loss: 66.543360
# Epoch Step: 76 Loss: 64.797492 Tokens per Sec: 64.345113 True Avg Loss: 66.184271
# Epoch Step: 81 Loss: 64.467369 Tokens per Sec: 64.249049 True Avg Loss: 65.669357
# Epoch Step: 86 Loss: 63.761146 Tokens per Sec: 65.187742 True Avg Loss: 64.760673
# Epoch Step: 91 Loss: 63.478423 Tokens per Sec: 64.461198 True Avg Loss: 64.381875
# Epoch Step: 96 Loss: 63.208649 Tokens per Sec: 64.682020 True Avg Loss: 64.053966
# Epoch Step: 1 Loss: 1.726136 Tokens per Sec: 120.108359 True Avg Loss: 172.613602
# Epoch Step: 6 Loss: 10.340030 Tokens per Sec: 118.128985 True Avg Loss: 176.768710
# val_avg_loss= 15.687465234497981
# val_true_avg_loss= 181.34194607204861
# val_diff_mean= 13.2648535
# val_diff_std= 2.4235961
# loss= 12.458606982049142
# Epoch= 98
# Epoch Step: 1 Loss: 63.064932 Tokens per Sec: 65.968078 True Avg Loss: 34.657219
# Epoch Step: 6 Loss: 63.455882 Tokens per Sec: 65.762895 True Avg Loss: 64.912289
# Epoch Step: 11 Loss: 64.045877 Tokens per Sec: 65.974473 True Avg Loss: 69.756124
# Epoch Step: 16 Loss: 64.484533 Tokens per Sec: 64.669828 True Avg Loss: 70.796491
# Epoch Step: 21 Loss: 63.955631 Tokens per Sec: 59.394777 True Avg Loss: 66.714514
# Epoch Step: 26 Loss: 64.663539 Tokens per Sec: 63.732289 True Avg Loss: 68.918369
# Epoch Step: 31 Loss: 64.522110 Tokens per Sec: 64.559189 True Avg Loss: 67.806063
# Epoch Step: 36 Loss: 63.611008 Tokens per Sec: 63.515704 True Avg Loss: 64.783338
# Epoch Step: 41 Loss: 64.369513 Tokens per Sec: 59.067435 True Avg Loss: 66.532572
# Epoch Step: 46 Loss: 64.328679 Tokens per Sec: 60.406584 True Avg Loss: 66.219002
# Epoch Step: 51 Loss: 63.873521 Tokens per Sec: 56.603684 True Avg Loss: 65.129288
# Epoch Step: 56 Loss: 63.319016 Tokens per Sec: 57.925525 True Avg Loss: 64.021319
# Epoch Step: 61 Loss: 63.100247 Tokens per Sec: 58.933016 True Avg Loss: 63.592734
# Epoch Step: 66 Loss: 63.166437 Tokens per Sec: 58.196379 True Avg Loss: 63.660866
# Epoch Step: 71 Loss: 63.931960 Tokens per Sec: 61.847965 True Avg Loss: 64.724215
# Epoch Step: 76 Loss: 63.344854 Tokens per Sec: 61.881898 True Avg Loss: 63.889769
# Epoch Step: 81 Loss: 64.006986 Tokens per Sec: 61.331644 True Avg Loss: 64.690149
# Epoch Step: 86 Loss: 64.967790 Tokens per Sec: 61.929250 True Avg Loss: 65.778417
# Epoch Step: 91 Loss: 64.971802 Tokens per Sec: 60.061392 True Avg Loss: 65.742281
# Epoch Step: 96 Loss: 65.627520 Tokens per Sec: 60.227034 True Avg Loss: 66.396630
# Epoch Step: 1 Loss: 1.510984 Tokens per Sec: 105.990037 True Avg Loss: 151.098404
# Epoch Step: 6 Loss: 9.009913 Tokens per Sec: 103.104565 True Avg Loss: 154.033249
# val_avg_loss= 13.880906381077043
# val_true_avg_loss= 160.38463507758246
# val_diff_mean= 12.414465
# val_diff_std= 2.346265
# loss= 11.018791722887345
# Epoch= 99
